# %% [markdown]
# # Join multiple rasters to many points, quickly

# %%
# Mask raster values > 360
# Build this so we can loop over a collection of rasters
# Do the aggregation operations per admin unit in Dask.DataFrames

import dask
import coiled
from dask.distributed import Client, LocalCluster, Lock
from dask.utils import SerializableLock
import dask.dataframe as dd

import pandas as pd
import geopandas as gpd
import spatialpandas as sp
import dask_geopandas as dg

import rioxarray as rx
import xarray as xr

import re
import os

from dask_control import *
from raster_vals_to_pts import *

import numpy as np
dask.config.set({"temporary-directory": "C:/Users/wb467985"})

# %%
dask.__version__
# Out:
# '2021.04.1'

# %%
bounds_1 = "P:/PAK/GEO/Boundaries/OCHA/pak_admbnda_adm1_ocha_pco_gaul_20181218.shp"
bounds_3 = "P:/PAK/GEO/Boundaries/OCHA/pak_admbnda_adm3_ocha_pco_gaul_20181218.shp"
# access_dir = "P:/PAK/Code/kpgit_robert/data/access/current/master"
# access_dir = r'P:\PAK\Code\OSMEfficacy\access\211214' # switching in access dir for BeforeOSMInvestment files
access_dir = r'P:\PAK\Code\kpgit_robert\data\access\globalFS' # switching in access dir for Global Friction surface fies
POINTS_URL = "../../data/interim/points_v15_full.csv"

# %%
#bounds_1 = "../../data/raw/geo/pak_adm_ocha_pco_gaul_20181218_SHP/pak_admbnda_adm1_ocha_pco_gaul_20181218.shp"
#bounds_3 = "../../data/raw/geo/pak_adm_ocha_pco_gaul_20181218_SHP/pak_admbnda_adm3_ocha_pco_gaul_20181218.shp"
#access_dir = "../../data/raw/access"
#POINTS_URL = "../../data/interim/points_v15_full.csv"

# %%
FRICTION_THRESHOLD = 150
DENSITY_THRESHOLD = 0.02

# change this to whatever the desired output projection is
DEST_CRS = 'EPSG:32642'

dcrs_int = int(re.findall('[0-9]+',DEST_CRS)[0])
dcrs_int
# Out:
# 32642

# %%
# define time period under study
# time_period = 'Current'
# time_period = 'BeforeOSMInvesment'
time_period = 'GlobalFS'

# %% [markdown]
# Instantiate Dask

# %%
client=get_dask_client(cluster_type='local',n_workers=4,processes=True,threads_per_worker=8)
client
# Out:
# distributed.nanny - WARNING - Restarting worker
# Client acquired. Restarting
# <Client: 'tcp://127.0.0.1:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# Read in CSV

# %%
pd.read_csv("../../data/interim/points_v15_full.csv", nrows=3)
# Out:
#         ix       POP     x_4326     y_4326              x             y  \
# 0  2148470  5.587176  73.545833  36.873889  905257.236250  4.090541e+06
# 1  2148497  5.587176  73.654444  36.873056  914950.266604  4.090916e+06
# 2  2148611  5.587176  73.394444  36.868889  891779.067584  4.089352e+06
#
#               ADM1_EN  ADM2_EN ADM3_EN Adm1_Code Adm2_Code Adm3_Code
# 0  Khyber Pakhtunkhwa  Chitral  Mastuj       PK2     PK206   PK20602
# 1  Khyber Pakhtunkhwa  Chitral  Mastuj       PK2     PK206   PK20602
# 2  Khyber Pakhtunkhwa  Chitral  Mastuj       PK2     PK206   PK20602

# %%
test_pts = pd.read_csv("../../data/interim/points_v15_full.csv", nrows=50000)

# %%
# Load Points
points = dd.read_csv(POINTS_URL, #storage_options=STORAGE_OPTS,
                     usecols = [
                         0, #"fid",
                         1, #"POP",
#                          2,#"x_wgs84",
#                          3,#"y_wgs84"
                         4,#"x",
                         5,#"y"
                         6,#"ADM1_EN"
                         7,#"ADM2_EN"
                         8,#"ADM3_EN"
                         9,#Adm1_Code
                         10,#Adm2_Code
                         11,#Adm3_Code
                     ],
                     header=0,
                     names=[
                         "ix",
                         "POP",
#                          "x_4326",
#                          "y_4326",
                         "x",
                         "y",
                         "ADM1_EN",
                         "ADM2_EN",
                         "ADM3_EN",
                         "Adm1_Code",
                         "Adm2_Code",
                         "Adm3_Code"
                     ],
                     dtype = {
                         "ix": int, 
                         "POP": float, 
#                          "x_4326": float, 
#                          "y_4326": float,
                         "x": float, 
                         "y": float,  
                         "ADM1_EN": str,
                         "ADM2_EN": str,
                         "ADM3_EN": str,
                         "Adm1_Code": str,
                         "Adm2_Code": str,
                         "Adm3_Code": str
                     },
                     na_values = ' ',
                     #blocksize='5mb'#'100mb'
                ).set_index('ix', drop=True, sorted=True)
points.head()
# Out:
#               POP              x             y             ADM1_EN  ADM2_EN  \
# ix
# 2148470  5.587176  905257.236250  4.090541e+06  Khyber Pakhtunkhwa  Chitral
# 2148497  5.587176  914950.266604  4.090916e+06  Khyber Pakhtunkhwa  Chitral
# 2148611  5.587176  891779.067584  4.089352e+06  Khyber Pakhtunkhwa  Chitral
# 2148619  5.587176  891830.046673  4.089324e+06  Khyber Pakhtunkhwa  Chitral
# 2148666  5.587176  895484.006545  4.089246e+06  Khyber Pakhtunkhwa  Chitral
#
#         ADM3_EN Adm1_Code Adm2_Code Adm3_Code
# ix
# 2148470  Mastuj       PK2     PK206   PK20602
# 2148497  Mastuj       PK2     PK206   PK20602
# 2148611  Mastuj       PK2     PK206   PK20602
# 2148619  Mastuj       PK2     PK206   PK20602
# 2148666  Mastuj       PK2     PK206   PK20602

# %% [markdown]
# Process rasters

# %%
rasters = {}
rlimit = len(os.listdir(access_dir))
r_ct = 0
for file in os.listdir(access_dir):
    if file.endswith("_COG.tif"):
#     if file.startswith(f'{time_period}_'):
        acc_rast = re.search(f'multimodal_(.*?)_COG.tif',os.path.basename(file)).group(1)
#         acc_rast = re.search(f'(.*?)_COG.tif',os.path.basename(file)).group(1)
        rasters[acc_rast] = f"{access_dir}/{file}"
        r_ct = r_ct + 1
        if r_ct >= rlimit:
            break

rasters
# Out:
# {'all_District_HQs': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_District_HQs_COG.tif',
#  'all_education_allboys': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_allboys_COG.tif',
#  'all_education_allgirls': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_allgirls_COG.tif',
#  'all_education_boys': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_boys_COG.tif',
#  'all_education_boys_high': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_boys_high_COG.tif',
#  'all_education_boys_middle': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_boys_middle_COG.tif',
#  'all_education_boys_primary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_boys_primary_COG.tif',
#  'all_education_girls': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_girls_COG.tif',
#  'all_education_girls_high': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_girls_high_COG.tif',
#  'all_education_girls_middle': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_girls_middle_COG.tif',
#  'all_education_girls_primary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_girls_primary_COG.tif',
#  'all_education_high': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_high_COG.tif',
#  'all_education_middle': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_middle_COG.tif',
#  'all_education_primary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_education_primary_COG.tif',
#  'all_health_family': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_family_COG.tif',
#  'all_health_pharmacies': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_pharmacies_COG.tif',
#  'all_health_primary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_primary_COG.tif',
#  'all_health_private': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_private_COG.tif',
#  'all_health_public': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_public_COG.tif',
#  'all_health_secondary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_secondary_COG.tif',
#  'all_health_tertiary': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_health_tertiary_COG.tif',
#  'all_markets_All': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_markets_All_COG.tif',
#  'all_markets_Central': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_markets_Central_COG.tif',
#  'all_Provincial_HQ': 'P:\\PAK\\Code\\kpgit_robert\\data\\access\\globalFS/GlobalFS_multimodal_all_Provincial_HQ_COG.tif'}

# %%
loaded_rasters = {}
for key in rasters:
    print(f"Persist raster: {key} at {rasters[key]}")
    raster = xr.open_rasterio(f"{rasters[key]}", 
#                                    chunks = (4, "auto", -1), # working
                                   chunks = ("auto", "auto", "auto"),
#                                            chunks = {'band' : "auto", 'x' : "auto", 'y' : "auto"},
                                   parse_coordinates=True)#.unify_chunks()
                                   #lock = True)
    loaded_rasters[key] = raster
# Out:
# Persist raster: all_District_HQs at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_District_HQs_COG.tif
# Persist raster: all_education_allboys at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_allboys_COG.tif
# Persist raster: all_education_allgirls at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_allgirls_COG.tif
# Persist raster: all_education_boys at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_boys_COG.tif
# Persist raster: all_education_boys_high at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_boys_high_COG.tif
# Persist raster: all_education_boys_middle at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_boys_middle_COG.tif
# Persist raster: all_education_boys_primary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_boys_primary_COG.tif
# Persist raster: all_education_girls at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_girls_COG.tif
# Persist raster: all_education_girls_high at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_girls_high_COG.tif
# Persist raster: all_education_girls_middle at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_girls_middle_COG.tif
# Persist raster: all_education_girls_primary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_girls_primary_COG.tif
# Persist raster: all_education_high at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_high_COG.tif
# Persist raster: all_education_middle at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_middle_COG.tif
# Persist raster: all_education_primary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_education_primary_COG.tif
# Persist raster: all_health_family at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_family_COG.tif
# Persist raster: all_health_pharmacies at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_pharmacies_COG.tif
# Persist raster: all_health_primary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_primary_COG.tif
# Persist raster: all_health_private at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_private_COG.tif
# Persist raster: all_health_public at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_public_COG.tif
# Persist raster: all_health_secondary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_secondary_COG.tif
# Persist raster: all_health_tertiary at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_health_tertiary_COG.tif
# Persist raster: all_markets_All at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_markets_All_COG.tif
# Persist raster: all_markets_Central at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_markets_Central_COG.tif
# Persist raster: all_Provincial_HQ at P:\PAK\Code\kpgit_robert\data\access\globalFS/GlobalFS_multimodal_all_Provincial_HQ_COG.tif

# %%
# THESE MUST BE COGS
rasters_ds = (
    xr.Dataset(loaded_rasters)
    .sel(band=1)
    .map(lambda arr: arr.where(arr != arr.nodatavals[0]))
)

# %%
# points.head()

# %% [markdown]
# Process points onto rasters (lazy execution)

# %%
rasters_ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (y: 808, x: 571)
# Coordinates:
#     band                         int32 1
#   * y                            (y) float64 4.114e+06 4.113e+06 ... 3.429e+06
#   * x                            (x) float64 5.031e+05 5.04e+05 ... 9.871e+05
# Data variables: (12/24)
#     all_District_HQs             (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_education_allboys        (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_education_allgirls       (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_education_boys           (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_education_boys_high      (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_education_boys_middle    (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     ...                           ...
#     all_health_public            (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_health_secondary         (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_health_tertiary          (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_markets_All              (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_markets_Central          (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>
#     all_Provincial_HQ            (y, x) float32 dask.array<chunksize=(808, 571), meta=np.ndarray>

# %%
rasters_ds['all_education_allgirls']
# Out:
# <xarray.DataArray 'all_education_allgirls' (y: 808, x: 571)>
# dask.array<where, shape=(808, 571), dtype=float32, chunksize=(808, 571), chunktype=numpy.ndarray>
# Coordinates:
#     band     int32 1
#   * y        (y) float64 4.114e+06 4.113e+06 4.113e+06 ... 3.43e+06 3.429e+06
#   * x        (x) float64 5.031e+05 5.04e+05 5.048e+05 ... 9.863e+05 9.871e+05
# Attributes:
#     transform:           (849.0613623253719, 0.0, 502717.4153788643, 0.0, -84...
#     crs:                 +init=epsg:32642
#     res:                 (849.0613623253719, 849.2630171967655)
#     is_tiled:            1
#     nodatavals:          (-3.4028234663852886e+38,)
#     scales:              (1.0,)
#     offsets:             (0.0,)
#     AREA_OR_POINT:       Area
#     OVR_RESAMPLING_ALG:  NEAREST

# %%
rasters_ds['BeforeOSMInvestment_childwalk_dry_education_allgirls']
# Out:
# <xarray.DataArray 'BeforeOSMInvestment_childwalk_dry_education_allgirls' (y: 21136, x: 17193)>
# dask.array<where, shape=(21136, 17193), dtype=float32, chunksize=(487, 17193), chunktype=numpy.ndarray>
# Coordinates:
#     band     int32 1
#   * y        (y) float64 4.115e+06 4.115e+06 4.115e+06 ... 3.443e+06 3.443e+06
#   * x        (x) float64 5.024e+05 5.025e+05 5.025e+05 ... 9.878e+05 9.878e+05
# Attributes:
#     transform:           (28.23254382673943, 0.0, 502425.3974356071, 0.0, -31...
#     crs:                 +init=epsg:32642
#     res:                 (28.23254382673943, 31.766168813716423)
#     is_tiled:            1
#     nodatavals:          (-99999.0,)
#     scales:              (1.0,)
#     offsets:             (0.0,)
#     AREA_OR_POINT:       Area
#     OVR_RESAMPLING_ALG:  NEAREST

# %%
points_xr.head()
# Out:
# <xarray.Dataset>
# Dimensions:  (ix: 5)
# Coordinates:
#   * ix       (ix) int64 2148470 2148497 2148611 2148619 2148666
# Data variables:
#     x        (ix) float64 9.053e+05 9.15e+05 8.918e+05 8.918e+05 8.955e+05
#     y        (ix) float64 4.091e+06 4.091e+06 4.089e+06 4.089e+06 4.089e+06

# %%
test_pts
# Out:
#             ix        POP     x_4326     y_4326              x             y  \
# 0      2148470   5.587176  73.545833  36.873889  905257.236250  4.090541e+06
# 1      2148497   5.587176  73.654444  36.873056  914950.266604  4.090916e+06
# 2      2148611   5.587176  73.394444  36.868889  891779.067584  4.089352e+06
# 3      2148619   5.587176  73.395000  36.868611  891830.046673  4.089324e+06
# 4      2148666   5.587176  73.435833  36.866389  895484.006545  4.089246e+06
# ...        ...        ...        ...        ...            ...           ...
# 49995  2274365  83.226013  73.224861  35.268611  884378.373393  3.911023e+06
# 49996  2274366  41.613007  73.225370  35.268426  884425.610930  3.911005e+06
# 49997  2274367  83.226013  73.225556  35.268611  884441.592421  3.911026e+06
# 49998  2274368  41.613007  73.225833  35.268611  884466.880037  3.911027e+06
# 49999  2274369  41.613007  73.229861  35.268611  884833.550815  3.911043e+06
#
#                   ADM1_EN   ADM2_EN ADM3_EN Adm1_Code Adm2_Code Adm3_Code
# 0      Khyber Pakhtunkhwa   Chitral  Mastuj       PK2     PK206   PK20602
# 1      Khyber Pakhtunkhwa   Chitral  Mastuj       PK2     PK206   PK20602
# 2      Khyber Pakhtunkhwa   Chitral  Mastuj       PK2     PK206   PK20602
# 3      Khyber Pakhtunkhwa   Chitral  Mastuj       PK2     PK206   PK20602
# 4      Khyber Pakhtunkhwa   Chitral  Mastuj       PK2     PK206   PK20602
# ...                   ...       ...     ...       ...       ...       ...
# 49995  Khyber Pakhtunkhwa  Kohistan   Dassu       PK2     PK212   PK21201
# 49996  Khyber Pakhtunkhwa  Kohistan   Dassu       PK2     PK212   PK21201
# 49997  Khyber Pakhtunkhwa  Kohistan   Dassu       PK2     PK212   PK21201
# 49998  Khyber Pakhtunkhwa  Kohistan   Dassu       PK2     PK212   PK21201
# 49999  Khyber Pakhtunkhwa  Kohistan   Dassu       PK2     PK212   PK21201
#
# [50000 rows x 12 columns]

# %%
points_xr = xr.Dataset.from_dataframe(test_pts[["x", "y"]])

# Select pixel values at points
# FOR MAKSIM -- so basically, we convert the points to an aligned raster dataset, select values that way, then return the values to a points dataset?
pixel_values = rasters_ds['all_health_secondary'].sel(x=points_xr.x, y=points_xr.y, method="nearest")

# %%
pixel_values_df = pixel_values.reset_coords(drop=True).to_dataframe(name='test')

# %%
pixel_values_df.sort_values('test',ascending=False)
# Out:
#        test
# index
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 49995   NaN
# 49996   NaN
# 49997   NaN
# 49998   NaN
# 49999   NaN
#
# [50000 rows x 1 columns]

# %%
# map pixel values to the points by relating the master Xarray dataset (not the individual TIF rasters) to the points
df_pixels = pixel_values_at_points(rasters_ds['all_health_secondary'], points)
# df_pixels.head()

# %%
df_pixels.compute()
# Out:
# []

# %%
# df_pixels = df_pixels[df_pixels.dry_education_primary < FRICTION_THRESHOLD]
df_pixels = df_pixels[df_pixels.all_education_primary < FRICTION_THRESHOLD]
df_pixels = df_pixels.loc[:,~df_pixels.columns.duplicated()]
df_pixels = df_pixels.persist()

# %% [markdown]
# Basic data manipulations

# %%
# Get Pops by Adm2_Code
adm2_pop = df_pixels.groupby('Adm2_Code')['POP'].sum().to_frame("adm2_pop")

# Get Pops by CBS Ward
adm3_pop = df_pixels.groupby('Adm3_Code')['POP'].sum().to_frame("adm3_pop")

# %%
# Merge the Pops into Ref DF
df_pixels = dd.merge(df_pixels, adm2_pop, how = 'left', left_on="Adm2_Code", right_index=True)
df_pixels = dd.merge(df_pixels, adm3_pop, how = 'left', left_on="Adm3_Code", right_index=True)

#points = points.persist()
df_pixels = df_pixels.persist()

# %%
df_pixels

# %%
df_pixels.head()

# %%
# Calculate the population weight of each pixel within its enclosing admin area -- e.g. 10 pixel population for a 100 population admin - 0.1 weight
df_pixels['wt_adm_2'] = (df_pixels['POP'] / df_pixels['adm2_pop'])
df_pixels['wt_adm_3'] = (df_pixels['POP'] / df_pixels['adm3_pop'])

# %% [markdown]
# Create a column per raster that we will populate with the corresponding raster's value

# %%
adm2_avg_cols = []
adm3_avg_cols = []

for rkey in rasters:
    hrs_col = f"{rkey}"
    avg_col_adm_2 = f"{rkey}_avg_adm2"
    avg_col_adm_3 = f"{rkey}_avg_adm3"
    df_pixels[avg_col_adm_2] = df_pixels[hrs_col] * df_pixels['wt_adm_2']
    df_pixels[avg_col_adm_3] = df_pixels[hrs_col] * df_pixels['wt_adm_3']
    
    adm2_avg_cols.append(avg_col_adm_2)
    adm3_avg_cols.append(avg_col_adm_3)

# %%
print(",".join(adm2_avg_cols))
print(",".join(adm3_avg_cols))

# %% [markdown]
# Aggregate per admin the column values

# %%
adm2_final = df_pixels.groupby(['Adm2_Code'])[adm2_avg_cols].sum().reset_index()
adm3_final = df_pixels.groupby(['Adm3_Code'])[adm3_avg_cols].sum().reset_index()

# %% [markdown]
# Export

# %%
adm2_output = f"../../data/outputs/{time_period}_adm2_mean.csv"
adm3_output = f"../../data/outputs/{time_period}_adm3_mean.csv"
df_pixels_out = f"../../data/outputs/{time_period}_df_pixels_final-*.csv" # make sure you have a * or it will output parquet files

# %%
# %time
adm2_final.to_csv(adm2_output, single_file=True)
# Out:
# Wall time: 0 ns
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40748/3072691957.py in <module>
#       1 get_ipython().run_line_magic('time', '')
# ----> 2 adm2_final.to_csv(adm2_output, single_file=True)
#
# NameError: name 'adm2_final' is not defined

# %%
# %time
adm3_final.to_csv(adm3_output, single_file=True)

# %%
df_pixels = df_pixels.repartition(partition_size="100MB")

# %%
# %time
df_pixels.to_csv(df_pixels_out, single_file=False)
# Out:
# Wall time: 0 ns
# ['P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-00.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-01.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-02.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-03.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-04.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-05.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-06.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-07.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-08.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-09.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-10.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-11.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-12.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-13.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-14.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-15.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-16.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-17.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-18.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-19.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-20.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-21.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-22.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-23.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-24.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-25.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-26.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-27.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-28.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-29.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-30.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-31.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-32.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-33.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-34.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-35.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-36.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-37.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-38.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-39.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-40.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-41.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-42.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-43.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-44.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-45.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-46.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-47.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-48.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-49.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-50.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-51.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-52.csv',
#  'P:/PAK/Code/kpgit/kpgit/data/outputs/BeforeOSMInvesment_df_pixels_final-53.csv']
