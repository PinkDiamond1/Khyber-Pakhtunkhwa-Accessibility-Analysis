# %% [markdown]
# # Convert proposed road speed rasters to access surfaces

# %% [markdown]
# This notebook merges each of the new speed rasters to the "main" friction surface for the analysis extent area, generating a new friction surface specific to that road. We use that friction surface to generate accessibility surfaces specific to that road

# %%
import os, sys
from datetime import date

import numpy as np
import re

import rasterio
from rasterio import features, transform
from rasterio.merge import merge as merge
from rasterio.transform import Affine
from rasterio.io import MemoryFile

import rio_cogeo
from rio_cogeo.cogeo import cog_translate

import pandas as pd
import geopandas as gpd

import shapely
from shapely.geometry import shape, box, MultiPoint, Point, Polygon

import skimage.graph as graph
sys.path.append('../../src/')
import GOSTnets.GOSTNets as gn
import GOSTNets_Raster.src.GOSTNets_Raster.market_access as ma
from gostrocks.src.GOSTRocks.misc import tPrint

# %% [markdown]
# ## Setup

# %% [markdown]
# Dates

# %%
today = date.today().strftime("%d%m%y")

# %%
data_date = '211020'

# %% [markdown]
# Directories

# %%
geo_dir = r'P:\PAK\GEO'
data_dir = r'../../data'

rd_dir = r'roads'
dest_dir = r'destinations'
fric_dir = r'friction'
acc_dir = r'access'

# %% [markdown]
# Projections

# %%
# change this to whatever the desired output projection is
dest_crs = 'EPSG:32642'

# %% [markdown]
# Desired resolution of rasters

# %%
res = '31m'

# %% [markdown]
# Load in KP as clipping object

# %%
aoi = gpd.read_file(os.path.join(geo_dir,'Boundaries/OCHA/pak_admbnda_adm1_ocha_pco_gaul_20181218.shp'))
aoi = aoi[aoi['ADM1_EN'] == 'Khyber Pakhtunkhwa']
aoi = aoi.to_crs(dest_crs)

# Buffer the polygon by 20km so we take in nearby markets and roads that may be used
aoi.geometry = aoi.buffer(20000)

# %% [markdown]
# Destination files

# %%
# Use destinations prepared previously. This assumes they are in WGS84 and need to be reprojected to the project's metric CRS

dest_fils = {
    re.findall(r'KP_(.*?).gpkg',fil)[0]: gpd.clip(gpd.read_file(os.path.join(data_dir,dest_dir,fil))\
                                                  .set_crs(4326).to_crs(dest_crs),aoi) \
    for fil in os.listdir(os.path.join(data_dir,dest_dir)) if fil.endswith(".gpkg")
}

# %%
len(dest_fils)
# Out:
# 24

# %% [markdown]
# Slight adjustment to GOST's TT code: export rasters as Float32 to reduce file sizes

# %%
# adjust GOST's code to always export float32 rasters, as a space saving measure

def calculate_travel_time_slim(inH, mcp, destinations, out_raster = ''):
    ''' Calculate travel time raster
    
    INPUTS
        inH [rasterio object] - template raster used to identify locations of destinations
        mcp [skimage.graph.MCP_Geometric] - input graph
        destinations [geopandas df] - destinations for nearest calculations
        
    LINKS
        https://scikit-image.org/docs/0.7.0/api/skimage.graph.mcp.html#skimage.graph.mcp.MCP.find_costs
    '''
    # create skimage graph, force costs to float32 to save on space
    cities = ma.get_mcp_dests(inH, destinations)
    costs, traceback = mcp.find_costs(cities)
    costs = costs.astype(np.float32)
    if not out_raster == '':
        meta = inH.meta.copy()
        meta.update(dtype=costs.dtype)
        with rasterio.open(out_raster, 'w', **meta) as out:
            out.write_band(1, costs)
            
    return((costs, traceback))

# %% [markdown]
# ## Generate friction surfaces

# %% [markdown]
# Create lists of variable names to loop over

# %%
speed_cols = ['upgrade_dry_speed', 'upgrade_msn_speed', 'upgrade_winter_speed']

# %%
seasons = ['dry','msn','winter']

# %% [markdown]
# **Create a list of friction tif file paths** for roads that have not yet been computed into all-of-KP friction surfaces

# %%
# friction surfaces
fric_tifs = [os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//raw',file) \
            for file \
            in os.listdir(os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//raw',)) \
            if file.endswith(".tif")]

# %% [markdown]
# If doing this in multiple batches, use the below code. This is useful if you don't recieve all your roads files at once or find errors in some that need to be subsequently corrected.

# %%
# # create a list of already completed friction surfaces to exclude, so we don't waste time recreating data

# exclusion_lst = sorted(list(set([re.search('^([0-9]+)',file)[0] \
#             for file \
#             in os.listdir(os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP')) \
#             if file.endswith(".tif")]))) # change to whatever criteria you need

# # filter down friction tifs using the exclusion list

# fric_tifs = [file for file in fric_tifs \
#               if re.search('^[0-9]+',os.path.basename(file))[0] not in exclusion_lst]

# %%
fric_tifs[::10]

# %% [markdown]
# #### Merge files, convert to friction surfaces if necessary, and export

# %%
# create export dir if missing
if os.path.exists(os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP')) == False:
    os.mkdir(os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP'))
else:
    None

# %%
for seas in seasons:
    
    # name variables
    base_fric_rast_pth = f'KP_friction_{seas}_{data_date}_{res}_masked_final.tif'
    
    # load in base raster as DatasetReader
    base_fric_rast = rasterio.open(os.path.join(data_dir,fric_dir,f'{res}//current_w_proposed',base_fric_rast_pth),'r')
    base_profile = base_fric_rast.profile
    base_profile.update({'dtype':'float32'})
    
    # if merging to a friction surface

    for idx, tif in enumerate(fric_tifs):
    
        if seas in tif:
            
            # create variable for naming output file
            feat_name = os.path.splitext(os.path.basename(fric_tifs[idx]))[0]

            # countdown
            tPrint(f'{seas}, {idx + 1} of {len(fric_tifs)}, {feat_name}')

            # merge two raster datasets, always taking the lowest value (friction cost)
            merge_array, out_transform = merge([base_fric_rast,rasterio.open(tif,'r')],method='min')
            merge_array = merge_array.astype(np.float32)

            # export result
            out_name = f'{feat_name}_{res}.tif'.replace(' ','')

            with rasterio.open(
                os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP',out_name), 'w',**base_profile) as dst:
                dst.write(merge_array)
                
        else:
            None

# %% [markdown]
# ## Generate access surfaces to all destinations, for all roads, for every season

# %% [markdown]
# Roads

# %%
master_prop_rds = gpd.read_file(os.path.join(data_dir,rd_dir,f'Proposed_final//Proposed_roads_processed_{data_date}.gpkg'),driver="GPKG")

# %% [markdown]
# Populate a list of friction surface paths for roads that have not yet been computed into access surfaces

# %%
# friction surfaces
complete_fric_tifs = sorted([os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP',file) \
            for file \
            in os.listdir(os.path.join(data_dir,fric_dir,f'proposed_roads//{res}//allKP')) \
            if file.endswith(".tif")])

# %% [markdown]
# If doing this in multiple batches, use the below code.

# %%
# # create a list of already completed friction surfaces to exclude, so we don't waste time recreating data
# exclusion_lst = sorted(list(set([re.search('^([0-9]+)',file)[0] \
#             for file \
#             in os.listdir(os.path.join(data_dir,acc_dir,f'upgrade//{res}')) \
#             if 'dry' in file]))) # currently set up for walking rasters, change to whatever you need
#             if file.endswith(".tif")]))) # currently set up for walking rasters, change to whatever you need

# # filter down friction tifs using the exclusion list
# complete_fric_tifs = [file for file in complete_fric_tifs \
#               if re.search('^[0-9]+',os.path.basename(file))[0] not in exclusion_lst]

# %%
complete_fric_tifs[::10]
# Out:
# ['../../data\\friction\\proposed_roads//31m//allKP\\10_LowerChitral_upgrade_dry_friction_31m.tif',
#  '../../data\\friction\\proposed_roads//31m//allKP\\20_Hangu_upgrade_dry_friction_31m.tif',
#  '../../data\\friction\\proposed_roads//31m//allKP\\35_Karak_upgrade_dry_friction_31m.tif',
#  '../../data\\friction\\proposed_roads//31m//allKP\\53_Laki_upgrade_dry_friction_31m.tif',
#  '../../data\\friction\\proposed_roads//31m//allKP\\70_Bajaur_upgrade_dry_friction_31m.tif',
#  '../../data\\friction\\proposed_roads//31m//allKP\\81_Khuber_upgrade_dry_friction_31m.tif']

# %% [markdown]
# Generate access surfaces in a loop</br>**Warning**: This step is slow at large sizes! Run overnight or over a weekend even

# %%
# create export dir if missing
if os.path.exists(os.path.join(data_dir,acc_dir,f'upgrade//{res}')) == False:
    os.mkdir(os.path.join(data_dir,acc_dir,f'upgrade//{res}'))
else:
    None

# %%
# Loop to generate clipped access surfaces for all roads, in all seasons, to all destinations

for dest_idx, (dest_name, dest_gdf) in enumerate(dest_fils.items()):
    
    # countdown
    tPrint(f'{dest_idx + 1} of {len(dest_fils)} destinations: {dest_name}')
    
    for fric_idx, fric_tif_fil in enumerate(complete_fric_tifs):
        
        # important variables for filtering and naming
        
        season = re.findall(r'upgrade_(.*?)_friction',fric_tif_fil)[0]
        feat_name = os.path.splitext(os.path.basename(complete_fric_tifs[fric_idx]))[0].split('_friction')[0]
        sn = int(re.split(r'([0-9]+)',os.path.basename(complete_fric_tifs[fric_idx]))[1])
        
        # countdown
        tPrint(f'{fric_idx + 1} of {len(complete_fric_tifs)}, {dest_name}, {feat_name}')
        
        # create a bounding box for clipping all our inputs to the focus area for each road
        # the bbox extent = the distance to the Nth nearest destination + the length of the road + half a kilometer, as previously prepared

        buf_dist = master_prop_rds[master_prop_rds['SN'] == sn][f'{dest_name}_nth_nearest_distance'].values[0]
        bds = master_prop_rds[master_prop_rds['SN'] == sn].geometry.total_bounds
        bbox = box(bds[0],bds[1],bds[2],bds[3]).buffer(buf_dist)

        # clip friction surface
    
        with rasterio.open(fric_tif_fil) as fric_raw:
            fric_clip, fric_clip_tform = rasterio.mask.mask(fric_raw,[bbox],crop=True)
            fric_clip = fric_clip[0,:,:]
            fric_clip_profile = fric_raw.profile
            
            # create mcp object from clipped friction surface

            inD = np.nan_to_num(fric_clip,nan=10,posinf=10)
            mcp = graph.MCP_Geometric(inD)

        # update profile with new shape and tform

        fric_clip_profile.update({"height":fric_clip.shape[0],
                             "width":fric_clip.shape[1],
                             "transform" : fric_clip_tform})

        # Create a clipped raster in memory
        # This routine is a bit different from how this is done (via the clip_in_memory custom function) elsewhere in these notebooks as here we only seek a DatasetReader object, meaning the raster is not yet converted to a numpy array
        with MemoryFile() as memfile:
            with memfile.open(**fric_clip_profile) as dataset:
                dataset.write(fric_clip,indexes=1)

            # now re-open the memfile to create a DatasetReader object for the calculate_travel_times routine
            memfile.seek(0)
            fric_clip_in_mem = memfile.open()

        # clip input gdf
        
        clipped_gdf = gpd.clip(dest_gdf,bbox).set_crs(dest_crs)
            
        # compute costs and export
        # Note that costs around the margins of the clipped surface will be HIGHER because low-cost roads beyond the edges are missing. 
        # This is a byproduct of clipping (needed for space + time) that we'll sort in the next notebook
        
        costs, traceback = calculate_travel_time_slim(fric_clip_in_mem, mcp, clipped_gdf, \
                                                    os.path.join(data_dir,acc_dir,f'upgrade//{res}//{feat_name}_{dest_name}_access.tif'))
# Out:
# 07:32:47	1 of 24 destinations: District_HQs
# 07:32:47	1 of 59, District_HQs, 10_LowerChitral_upgrade_dry
# 07:34:17	2 of 59, District_HQs, 11_LowerChitral_upgrade_dry
# 07:36:52	3 of 59, District_HQs, 12_Kohistan_upgrade_dry
# 07:38:54	4 of 59, District_HQs, 13_Kohistan_upgrade_dry
# 07:39:44	5 of 59, District_HQs, 14_Kohistan_upgrade_dry
# 07:40:29	6 of 59, District_HQs, 15_Kohistan_upgrade_dry
# 07:41:10	7 of 59, District_HQs, 17_Torghar_upgrade_dry
# 07:41:40	8 of 59, District_HQs, 18_Torghar_upgrade_dry
# 07:42:39	9 of 59, District_HQs, 19_Hangu_upgrade_dry
# 07:43:03	10 of 59, District_HQs, 1_UpperChitral_upgrade_dry
# 07:46:40	11 of 59, District_HQs, 20_Hangu_upgrade_dry
# 07:47:51	12 of 59, District_HQs, 21_Hangu_upgrade_dry
# 07:48:29	13 of 59, District_HQs, 22_Hangu_upgrade_dry
# 07:49:02	14 of 59, District_HQs, 23_Hangu_upgrade_dry
# 07:49:23	15 of 59, District_HQs, 24_Karak_upgrade_dry
# 07:50:22	16 of 59, District_HQs, 25_Karak_upgrade_dry
# 07:51:43	17 of 59, District_HQs, 26_Karak_upgrade_dry
# 07:52:27	18 of 59, District_HQs, 2_UpperChitral_upgrade_dry
# 07:57:39	19 of 59, District_HQs, 31_Karak_upgrade_dry
# 07:58:20	20 of 59, District_HQs, 32_Karak_upgrade_dry
# 07:58:57	21 of 59, District_HQs, 35_Karak_upgrade_dry
# 07:59:37	22 of 59, District_HQs, 37_Karak_upgrade_dry
# 08:00:33	23 of 59, District_HQs, 38_Karak_upgrade_dry
# 08:01:29	24 of 59, District_HQs, 3_UpperChitral_upgrade_dry
# 08:06:07	25 of 59, District_HQs, 41_Karak_upgrade_dry
# 08:07:04	26 of 59, District_HQs, 42_Karak_upgrade_dry
# 08:07:51	27 of 59, District_HQs, 43_Karak_upgrade_dry
# 08:08:16	28 of 59, District_HQs, 4_UpperChitral_upgrade_dry
# 08:12:17	29 of 59, District_HQs, 50_Laki_upgrade_dry
# 08:14:17	30 of 59, District_HQs, 52_Laki_upgrade_dry
# 08:14:47	31 of 59, District_HQs, 53_Laki_upgrade_dry
# 08:17:31	32 of 59, District_HQs, 57_D.I.Khan_upgrade_dry
# 08:18:41	33 of 59, District_HQs, 59_D.I.Khan_upgrade_dry
# 08:20:30	34 of 59, District_HQs, 5_UpperChitral_upgrade_dry
# 08:25:00	35 of 59, District_HQs, 60_D.I.Khan_upgrade_dry
# 08:26:59	36 of 59, District_HQs, 61_Tank_upgrade_dry
# 08:28:03	37 of 59, District_HQs, 62_Tank_upgrade_dry
# 08:30:05	38 of 59, District_HQs, 63_Tank_upgrade_dry
# 08:32:00	39 of 59, District_HQs, 64_Tank_upgrade_dry
# 08:33:46	40 of 59, District_HQs, 6_LowerChitral_upgrade_dry
# 08:35:00	41 of 59, District_HQs, 70_Bajaur_upgrade_dry
# 08:35:32	42 of 59, District_HQs, 71_Bajaur_upgrade_dry
# 08:36:12	43 of 59, District_HQs, 72_Bajaur_upgrade_dry
# 08:36:46	44 of 59, District_HQs, 73_Bajaur_upgrade_dry
# 08:37:55	45 of 59, District_HQs, 74_Bajaur_upgrade_dry
# 08:38:21	46 of 59, District_HQs, 75_Bajaur_upgrade_dry
# 08:39:13	47 of 59, District_HQs, 77_Khuber_upgrade_dry
# 08:40:05	48 of 59, District_HQs, 78_Khuber_upgrade_dry
# 08:41:42	49 of 59, District_HQs, 7_LowerChitral_upgrade_dry
# 08:49:03	50 of 59, District_HQs, 80_Khuber_upgrade_dry
# 08:49:43	51 of 59, District_HQs, 81_Khuber_upgrade_dry
# 08:50:12	52 of 59, District_HQs, 82_Khuber_upgrade_dry
# 08:50:46	53 of 59, District_HQs, 83_Kurram_upgrade_dry
# 08:52:39	54 of 59, District_HQs, 84_Kurram_upgrade_dry
# 08:54:17	55 of 59, District_HQs, 85_NorthWaziristan_upgrade_dry
# 08:56:14	56 of 59, District_HQs, 86_NorthWaziristan_upgrade_dry
# 08:59:14	57 of 59, District_HQs, 87_NorthWaziristan_upgrade_dry
# 09:01:19	58 of 59, District_HQs, 8_LowerChitral_upgrade_dry
# 09:02:53	59 of 59, District_HQs, 9_LowerChitral_upgrade_dry
# 09:03:32	2 of 24 destinations: education_allboys
# 09:03:32	1 of 59, education_allboys, 10_LowerChitral_upgrade_dry
# 09:03:38	2 of 59, education_allboys, 11_LowerChitral_upgrade_dry
# 09:03:42	3 of 59, education_allboys, 12_Kohistan_upgrade_dry
# 09:03:59	4 of 59, education_allboys, 13_Kohistan_upgrade_dry
# 09:04:14	5 of 59, education_allboys, 14_Kohistan_upgrade_dry
# 09:04:20	6 of 59, education_allboys, 15_Kohistan_upgrade_dry
# 09:04:26	7 of 59, education_allboys, 17_Torghar_upgrade_dry
# 09:04:32	8 of 59, education_allboys, 18_Torghar_upgrade_dry
# 09:05:08	9 of 59, education_allboys, 19_Hangu_upgrade_dry
# 09:05:11	10 of 59, education_allboys, 1_UpperChitral_upgrade_dry
# 09:05:16	11 of 59, education_allboys, 20_Hangu_upgrade_dry
# 09:05:24	12 of 59, education_allboys, 21_Hangu_upgrade_dry
# 09:05:34	13 of 59, education_allboys, 22_Hangu_upgrade_dry
# 09:05:36	14 of 59, education_allboys, 23_Hangu_upgrade_dry
# 09:05:40	15 of 59, education_allboys, 24_Karak_upgrade_dry
# 09:05:43	16 of 59, education_allboys, 25_Karak_upgrade_dry
# 09:05:52	17 of 59, education_allboys, 26_Karak_upgrade_dry
# 09:05:55	18 of 59, education_allboys, 2_UpperChitral_upgrade_dry
# 09:06:24	19 of 59, education_allboys, 31_Karak_upgrade_dry
# 09:06:26	20 of 59, education_allboys, 32_Karak_upgrade_dry
# 09:06:29	21 of 59, education_allboys, 35_Karak_upgrade_dry
# 09:06:32	22 of 59, education_allboys, 37_Karak_upgrade_dry
# 09:06:34	23 of 59, education_allboys, 38_Karak_upgrade_dry
# 09:06:36	24 of 59, education_allboys, 3_UpperChitral_upgrade_dry
# 09:06:42	25 of 59, education_allboys, 41_Karak_upgrade_dry
# 09:06:48	26 of 59, education_allboys, 42_Karak_upgrade_dry
# 09:06:50	27 of 59, education_allboys, 43_Karak_upgrade_dry
# 09:06:54	28 of 59, education_allboys, 4_UpperChitral_upgrade_dry
# 09:06:58	29 of 59, education_allboys, 50_Laki_upgrade_dry
# 09:07:25	30 of 59, education_allboys, 52_Laki_upgrade_dry
# 09:07:27	31 of 59, education_allboys, 53_Laki_upgrade_dry
# 09:07:48	32 of 59, education_allboys, 57_D.I.Khan_upgrade_dry
# 09:08:02	33 of 59, education_allboys, 59_D.I.Khan_upgrade_dry
# 09:08:05	34 of 59, education_allboys, 5_UpperChitral_upgrade_dry
# 09:08:08	35 of 59, education_allboys, 60_D.I.Khan_upgrade_dry
# 09:08:17	36 of 59, education_allboys, 61_Tank_upgrade_dry
# 09:08:20	37 of 59, education_allboys, 62_Tank_upgrade_dry
# 09:08:35	38 of 59, education_allboys, 63_Tank_upgrade_dry
# 09:08:49	39 of 59, education_allboys, 64_Tank_upgrade_dry
# 09:08:53	40 of 59, education_allboys, 6_LowerChitral_upgrade_dry
# 09:09:02	41 of 59, education_allboys, 70_Bajaur_upgrade_dry
# 09:09:06	42 of 59, education_allboys, 71_Bajaur_upgrade_dry
# 09:09:12	43 of 59, education_allboys, 72_Bajaur_upgrade_dry
# 09:09:20	44 of 59, education_allboys, 73_Bajaur_upgrade_dry
# 09:09:37	45 of 59, education_allboys, 74_Bajaur_upgrade_dry
# 09:09:40	46 of 59, education_allboys, 75_Bajaur_upgrade_dry
# 09:09:44	47 of 59, education_allboys, 77_Khuber_upgrade_dry
# 09:10:05	48 of 59, education_allboys, 78_Khuber_upgrade_dry
# 09:10:41	49 of 59, education_allboys, 7_LowerChitral_upgrade_dry
# 09:13:14	50 of 59, education_allboys, 80_Khuber_upgrade_dry
# 09:13:21	51 of 59, education_allboys, 81_Khuber_upgrade_dry
# 09:13:26	52 of 59, education_allboys, 82_Khuber_upgrade_dry
# 09:13:32	53 of 59, education_allboys, 83_Kurram_upgrade_dry
# 09:13:36	54 of 59, education_allboys, 84_Kurram_upgrade_dry
# 09:13:42	55 of 59, education_allboys, 85_NorthWaziristan_upgrade_dry
# 09:13:48	56 of 59, education_allboys, 86_NorthWaziristan_upgrade_dry
# 09:14:14	57 of 59, education_allboys, 87_NorthWaziristan_upgrade_dry
# 09:14:32	58 of 59, education_allboys, 8_LowerChitral_upgrade_dry
# 09:14:57	59 of 59, education_allboys, 9_LowerChitral_upgrade_dry
# 09:15:01	3 of 24 destinations: education_allgirls
# 09:15:01	1 of 59, education_allgirls, 10_LowerChitral_upgrade_dry
# 09:15:07	2 of 59, education_allgirls, 11_LowerChitral_upgrade_dry
# 09:15:11	3 of 59, education_allgirls, 12_Kohistan_upgrade_dry
# 09:15:40	4 of 59, education_allgirls, 13_Kohistan_upgrade_dry
# 09:15:55	5 of 59, education_allgirls, 14_Kohistan_upgrade_dry
# 09:16:01	6 of 59, education_allgirls, 15_Kohistan_upgrade_dry
# 09:16:08	7 of 59, education_allgirls, 17_Torghar_upgrade_dry
# 09:16:15	8 of 59, education_allgirls, 18_Torghar_upgrade_dry
# 09:16:54	9 of 59, education_allgirls, 19_Hangu_upgrade_dry
# 09:16:58	10 of 59, education_allgirls, 1_UpperChitral_upgrade_dry
# 09:17:07	11 of 59, education_allgirls, 20_Hangu_upgrade_dry
# 09:17:19	12 of 59, education_allgirls, 21_Hangu_upgrade_dry
# 09:17:30	13 of 59, education_allgirls, 22_Hangu_upgrade_dry
# 09:17:32	14 of 59, education_allgirls, 23_Hangu_upgrade_dry
# 09:17:36	15 of 59, education_allgirls, 24_Karak_upgrade_dry
# 09:17:40	16 of 59, education_allgirls, 25_Karak_upgrade_dry
# 09:17:48	17 of 59, education_allgirls, 26_Karak_upgrade_dry
# 09:17:51	18 of 59, education_allgirls, 2_UpperChitral_upgrade_dry
# 09:18:20	19 of 59, education_allgirls, 31_Karak_upgrade_dry
# 09:18:22	20 of 59, education_allgirls, 32_Karak_upgrade_dry
# 09:18:24	21 of 59, education_allgirls, 35_Karak_upgrade_dry
# 09:18:26	22 of 59, education_allgirls, 37_Karak_upgrade_dry
# 09:18:28	23 of 59, education_allgirls, 38_Karak_upgrade_dry
# 09:18:30	24 of 59, education_allgirls, 3_UpperChitral_upgrade_dry
# 09:18:42	25 of 59, education_allgirls, 41_Karak_upgrade_dry
# 09:18:48	26 of 59, education_allgirls, 42_Karak_upgrade_dry
# 09:18:51	27 of 59, education_allgirls, 43_Karak_upgrade_dry
# 09:18:54	28 of 59, education_allgirls, 4_UpperChitral_upgrade_dry
# 09:18:58	29 of 59, education_allgirls, 50_Laki_upgrade_dry
# 09:19:23	30 of 59, education_allgirls, 52_Laki_upgrade_dry
# 09:19:25	31 of 59, education_allgirls, 53_Laki_upgrade_dry
# 09:19:46	32 of 59, education_allgirls, 57_D.I.Khan_upgrade_dry
# 09:20:00	33 of 59, education_allgirls, 59_D.I.Khan_upgrade_dry
# 09:20:03	34 of 59, education_allgirls, 5_UpperChitral_upgrade_dry
# 09:20:06	35 of 59, education_allgirls, 60_D.I.Khan_upgrade_dry
# 09:20:15	36 of 59, education_allgirls, 61_Tank_upgrade_dry
# 09:20:18	37 of 59, education_allgirls, 62_Tank_upgrade_dry
# 09:20:36	38 of 59, education_allgirls, 63_Tank_upgrade_dry
# 09:20:48	39 of 59, education_allgirls, 64_Tank_upgrade_dry
# 09:20:51	40 of 59, education_allgirls, 6_LowerChitral_upgrade_dry
# 09:21:01	41 of 59, education_allgirls, 70_Bajaur_upgrade_dry
# 09:21:05	42 of 59, education_allgirls, 71_Bajaur_upgrade_dry
# 09:21:12	43 of 59, education_allgirls, 72_Bajaur_upgrade_dry
# 09:21:22	44 of 59, education_allgirls, 73_Bajaur_upgrade_dry
# 09:21:44	45 of 59, education_allgirls, 74_Bajaur_upgrade_dry
# 09:21:47	46 of 59, education_allgirls, 75_Bajaur_upgrade_dry
# 09:21:51	47 of 59, education_allgirls, 77_Khuber_upgrade_dry
# 09:22:10	48 of 59, education_allgirls, 78_Khuber_upgrade_dry
# 09:22:42	49 of 59, education_allgirls, 7_LowerChitral_upgrade_dry
# 09:25:12	50 of 59, education_allgirls, 80_Khuber_upgrade_dry
# 09:25:19	51 of 59, education_allgirls, 81_Khuber_upgrade_dry
# 09:25:24	52 of 59, education_allgirls, 82_Khuber_upgrade_dry
# 09:25:30	53 of 59, education_allgirls, 83_Kurram_upgrade_dry
# 09:25:33	54 of 59, education_allgirls, 84_Kurram_upgrade_dry
# 09:25:40	55 of 59, education_allgirls, 85_NorthWaziristan_upgrade_dry
# 09:25:46	56 of 59, education_allgirls, 86_NorthWaziristan_upgrade_dry
# 09:26:10	57 of 59, education_allgirls, 87_NorthWaziristan_upgrade_dry
# 09:26:29	58 of 59, education_allgirls, 8_LowerChitral_upgrade_dry
# 09:26:54	59 of 59, education_allgirls, 9_LowerChitral_upgrade_dry
# 09:26:58	4 of 24 destinations: education_boys
# 09:26:58	1 of 59, education_boys, 10_LowerChitral_upgrade_dry
# 09:27:03	2 of 59, education_boys, 11_LowerChitral_upgrade_dry
# 09:27:06	3 of 59, education_boys, 12_Kohistan_upgrade_dry
# 09:27:23	4 of 59, education_boys, 13_Kohistan_upgrade_dry
# 09:27:38	5 of 59, education_boys, 14_Kohistan_upgrade_dry
# 09:27:44	6 of 59, education_boys, 15_Kohistan_upgrade_dry
# 09:27:50	7 of 59, education_boys, 17_Torghar_upgrade_dry
# 09:27:54	8 of 59, education_boys, 18_Torghar_upgrade_dry
# 09:28:29	9 of 59, education_boys, 19_Hangu_upgrade_dry
# 09:28:33	10 of 59, education_boys, 1_UpperChitral_upgrade_dry
# 09:28:38	11 of 59, education_boys, 20_Hangu_upgrade_dry
# 09:28:46	12 of 59, education_boys, 21_Hangu_upgrade_dry
# 09:28:56	13 of 59, education_boys, 22_Hangu_upgrade_dry
# 09:28:57	14 of 59, education_boys, 23_Hangu_upgrade_dry
# 09:29:01	15 of 59, education_boys, 24_Karak_upgrade_dry
# 09:29:05	16 of 59, education_boys, 25_Karak_upgrade_dry
# 09:29:14	17 of 59, education_boys, 26_Karak_upgrade_dry
# 09:29:17	18 of 59, education_boys, 2_UpperChitral_upgrade_dry
# 09:29:46	19 of 59, education_boys, 31_Karak_upgrade_dry
# 09:29:48	20 of 59, education_boys, 32_Karak_upgrade_dry
# 09:29:50	21 of 59, education_boys, 35_Karak_upgrade_dry
# 09:29:53	22 of 59, education_boys, 37_Karak_upgrade_dry
# 09:29:54	23 of 59, education_boys, 38_Karak_upgrade_dry
# 09:29:56	24 of 59, education_boys, 3_UpperChitral_upgrade_dry
# 09:30:02	25 of 59, education_boys, 41_Karak_upgrade_dry
# 09:30:07	26 of 59, education_boys, 42_Karak_upgrade_dry
# 09:30:10	27 of 59, education_boys, 43_Karak_upgrade_dry
# 09:30:13	28 of 59, education_boys, 4_UpperChitral_upgrade_dry
# 09:30:16	29 of 59, education_boys, 50_Laki_upgrade_dry
# 09:30:42	30 of 59, education_boys, 52_Laki_upgrade_dry
# 09:30:44	31 of 59, education_boys, 53_Laki_upgrade_dry
# 09:31:06	32 of 59, education_boys, 57_D.I.Khan_upgrade_dry
# 09:31:21	33 of 59, education_boys, 59_D.I.Khan_upgrade_dry
# 09:31:24	34 of 59, education_boys, 5_UpperChitral_upgrade_dry
# 09:31:28	35 of 59, education_boys, 60_D.I.Khan_upgrade_dry
# 09:31:36	36 of 59, education_boys, 61_Tank_upgrade_dry
# 09:31:40	37 of 59, education_boys, 62_Tank_upgrade_dry
# 09:31:55	38 of 59, education_boys, 63_Tank_upgrade_dry
# 09:32:07	39 of 59, education_boys, 64_Tank_upgrade_dry
# 09:32:11	40 of 59, education_boys, 6_LowerChitral_upgrade_dry
# 09:32:19	41 of 59, education_boys, 70_Bajaur_upgrade_dry
# 09:32:23	42 of 59, education_boys, 71_Bajaur_upgrade_dry
# 09:32:30	43 of 59, education_boys, 72_Bajaur_upgrade_dry
# 09:32:39	44 of 59, education_boys, 73_Bajaur_upgrade_dry
# 09:32:58	45 of 59, education_boys, 74_Bajaur_upgrade_dry
# 09:33:01	46 of 59, education_boys, 75_Bajaur_upgrade_dry
# 09:33:05	47 of 59, education_boys, 77_Khuber_upgrade_dry
# 09:33:23	48 of 59, education_boys, 78_Khuber_upgrade_dry
# 09:33:59	49 of 59, education_boys, 7_LowerChitral_upgrade_dry
# 09:36:34	50 of 59, education_boys, 80_Khuber_upgrade_dry
# 09:36:43	51 of 59, education_boys, 81_Khuber_upgrade_dry
# 09:36:47	52 of 59, education_boys, 82_Khuber_upgrade_dry
# 09:36:53	53 of 59, education_boys, 83_Kurram_upgrade_dry
# 09:36:57	54 of 59, education_boys, 84_Kurram_upgrade_dry
# 09:37:02	55 of 59, education_boys, 85_NorthWaziristan_upgrade_dry
# 09:37:08	56 of 59, education_boys, 86_NorthWaziristan_upgrade_dry
# 09:37:32	57 of 59, education_boys, 87_NorthWaziristan_upgrade_dry
# 09:37:51	58 of 59, education_boys, 8_LowerChitral_upgrade_dry
# 09:38:17	59 of 59, education_boys, 9_LowerChitral_upgrade_dry
# 09:38:20	5 of 24 destinations: education_boys_high
# 09:38:20	1 of 59, education_boys_high, 10_LowerChitral_upgrade_dry
# 09:38:34	2 of 59, education_boys_high, 11_LowerChitral_upgrade_dry
# 09:38:50	3 of 59, education_boys_high, 12_Kohistan_upgrade_dry
# 09:40:02	4 of 59, education_boys_high, 13_Kohistan_upgrade_dry
# 09:40:23	5 of 59, education_boys_high, 14_Kohistan_upgrade_dry
# 09:40:36	6 of 59, education_boys_high, 15_Kohistan_upgrade_dry
# 09:40:52	7 of 59, education_boys_high, 17_Torghar_upgrade_dry
# 09:41:06	8 of 59, education_boys_high, 18_Torghar_upgrade_dry
# 09:41:54	9 of 59, education_boys_high, 19_Hangu_upgrade_dry
# 09:42:05	10 of 59, education_boys_high, 1_UpperChitral_upgrade_dry
# 09:42:20	11 of 59, education_boys_high, 20_Hangu_upgrade_dry
# 09:42:34	12 of 59, education_boys_high, 21_Hangu_upgrade_dry
# 09:42:47	13 of 59, education_boys_high, 22_Hangu_upgrade_dry
# 09:42:53	14 of 59, education_boys_high, 23_Hangu_upgrade_dry
# 09:43:03	15 of 59, education_boys_high, 24_Karak_upgrade_dry
# 09:43:09	16 of 59, education_boys_high, 25_Karak_upgrade_dry
# 09:43:25	17 of 59, education_boys_high, 26_Karak_upgrade_dry
# 09:43:31	18 of 59, education_boys_high, 2_UpperChitral_upgrade_dry
# 09:44:12	19 of 59, education_boys_high, 31_Karak_upgrade_dry
# 09:44:16	20 of 59, education_boys_high, 32_Karak_upgrade_dry
# 09:44:22	21 of 59, education_boys_high, 35_Karak_upgrade_dry
# 09:44:34	22 of 59, education_boys_high, 37_Karak_upgrade_dry
# 09:44:37	23 of 59, education_boys_high, 38_Karak_upgrade_dry
# 09:44:40	24 of 59, education_boys_high, 3_UpperChitral_upgrade_dry
# 09:45:01	25 of 59, education_boys_high, 41_Karak_upgrade_dry
# 09:45:09	26 of 59, education_boys_high, 42_Karak_upgrade_dry
# 09:45:16	27 of 59, education_boys_high, 43_Karak_upgrade_dry
# 09:45:21	28 of 59, education_boys_high, 4_UpperChitral_upgrade_dry
# 09:45:32	29 of 59, education_boys_high, 50_Laki_upgrade_dry
# 09:46:15	30 of 59, education_boys_high, 52_Laki_upgrade_dry
# 09:46:19	31 of 59, education_boys_high, 53_Laki_upgrade_dry
# 09:46:47	32 of 59, education_boys_high, 57_D.I.Khan_upgrade_dry
# 09:47:06	33 of 59, education_boys_high, 59_D.I.Khan_upgrade_dry
# 09:47:16	34 of 59, education_boys_high, 5_UpperChitral_upgrade_dry
# 09:47:23	35 of 59, education_boys_high, 60_D.I.Khan_upgrade_dry
# 09:47:45	36 of 59, education_boys_high, 61_Tank_upgrade_dry
# 09:47:51	37 of 59, education_boys_high, 62_Tank_upgrade_dry
# 09:48:13	38 of 59, education_boys_high, 63_Tank_upgrade_dry
# 09:48:31	39 of 59, education_boys_high, 64_Tank_upgrade_dry
# 09:48:36	40 of 59, education_boys_high, 6_LowerChitral_upgrade_dry
# 09:48:56	41 of 59, education_boys_high, 70_Bajaur_upgrade_dry
# 09:49:03	42 of 59, education_boys_high, 71_Bajaur_upgrade_dry
# 09:49:17	43 of 59, education_boys_high, 72_Bajaur_upgrade_dry
# 09:49:32	44 of 59, education_boys_high, 73_Bajaur_upgrade_dry
# 09:50:02	45 of 59, education_boys_high, 74_Bajaur_upgrade_dry
# 09:50:10	46 of 59, education_boys_high, 75_Bajaur_upgrade_dry
# 09:50:24	47 of 59, education_boys_high, 77_Khuber_upgrade_dry
# 09:50:48	48 of 59, education_boys_high, 78_Khuber_upgrade_dry
# 09:51:32	49 of 59, education_boys_high, 7_LowerChitral_upgrade_dry
# 09:54:40	50 of 59, education_boys_high, 80_Khuber_upgrade_dry
# 09:54:55	51 of 59, education_boys_high, 81_Khuber_upgrade_dry
# 09:55:06	52 of 59, education_boys_high, 82_Khuber_upgrade_dry
# 09:55:18	53 of 59, education_boys_high, 83_Kurram_upgrade_dry
# 09:55:24	54 of 59, education_boys_high, 84_Kurram_upgrade_dry
# 09:55:42	55 of 59, education_boys_high, 85_NorthWaziristan_upgrade_dry
# 09:55:59	56 of 59, education_boys_high, 86_NorthWaziristan_upgrade_dry
# 09:56:46	57 of 59, education_boys_high, 87_NorthWaziristan_upgrade_dry
# 09:57:43	58 of 59, education_boys_high, 8_LowerChitral_upgrade_dry
# 09:58:24	59 of 59, education_boys_high, 9_LowerChitral_upgrade_dry
# 09:58:38	6 of 24 destinations: education_boys_middle
# 09:58:38	1 of 59, education_boys_middle, 10_LowerChitral_upgrade_dry
# 09:58:54	2 of 59, education_boys_middle, 11_LowerChitral_upgrade_dry
# 09:59:01	3 of 59, education_boys_middle, 12_Kohistan_upgrade_dry
# 09:59:46	4 of 59, education_boys_middle, 13_Kohistan_upgrade_dry
# 10:00:11	5 of 59, education_boys_middle, 14_Kohistan_upgrade_dry
# 10:00:18	6 of 59, education_boys_middle, 15_Kohistan_upgrade_dry
# 10:00:32	7 of 59, education_boys_middle, 17_Torghar_upgrade_dry
# 10:00:40	8 of 59, education_boys_middle, 18_Torghar_upgrade_dry
# 10:01:23	9 of 59, education_boys_middle, 19_Hangu_upgrade_dry
# 10:01:38	10 of 59, education_boys_middle, 1_UpperChitral_upgrade_dry
# 10:02:00	11 of 59, education_boys_middle, 20_Hangu_upgrade_dry
# 10:02:22	12 of 59, education_boys_middle, 21_Hangu_upgrade_dry
# 10:02:38	13 of 59, education_boys_middle, 22_Hangu_upgrade_dry
# 10:02:44	14 of 59, education_boys_middle, 23_Hangu_upgrade_dry
# 10:02:53	15 of 59, education_boys_middle, 24_Karak_upgrade_dry
# 10:02:59	16 of 59, education_boys_middle, 25_Karak_upgrade_dry
# 10:03:19	17 of 59, education_boys_middle, 26_Karak_upgrade_dry
# 10:03:25	18 of 59, education_boys_middle, 2_UpperChitral_upgrade_dry
# 10:04:08	19 of 59, education_boys_middle, 31_Karak_upgrade_dry
# 10:04:11	20 of 59, education_boys_middle, 32_Karak_upgrade_dry
# 10:04:15	21 of 59, education_boys_middle, 35_Karak_upgrade_dry
# 10:04:25	22 of 59, education_boys_middle, 37_Karak_upgrade_dry
# 10:04:32	23 of 59, education_boys_middle, 38_Karak_upgrade_dry
# 10:04:36	24 of 59, education_boys_middle, 3_UpperChitral_upgrade_dry
# 10:04:59	25 of 59, education_boys_middle, 41_Karak_upgrade_dry
# 10:05:13	26 of 59, education_boys_middle, 42_Karak_upgrade_dry
# 10:05:21	27 of 59, education_boys_middle, 43_Karak_upgrade_dry
# 10:05:27	28 of 59, education_boys_middle, 4_UpperChitral_upgrade_dry
# 10:05:42	29 of 59, education_boys_middle, 50_Laki_upgrade_dry
# 10:06:23	30 of 59, education_boys_middle, 52_Laki_upgrade_dry
# 10:06:26	31 of 59, education_boys_middle, 53_Laki_upgrade_dry
# 10:06:55	32 of 59, education_boys_middle, 57_D.I.Khan_upgrade_dry
# 10:07:18	33 of 59, education_boys_middle, 59_D.I.Khan_upgrade_dry
# 10:07:25	34 of 59, education_boys_middle, 5_UpperChitral_upgrade_dry
# 10:07:37	35 of 59, education_boys_middle, 60_D.I.Khan_upgrade_dry
# 10:07:51	36 of 59, education_boys_middle, 61_Tank_upgrade_dry
# 10:08:07	37 of 59, education_boys_middle, 62_Tank_upgrade_dry
# 10:08:28	38 of 59, education_boys_middle, 63_Tank_upgrade_dry
# 10:08:46	39 of 59, education_boys_middle, 64_Tank_upgrade_dry
# 10:08:52	40 of 59, education_boys_middle, 6_LowerChitral_upgrade_dry
# 10:09:09	41 of 59, education_boys_middle, 70_Bajaur_upgrade_dry
# 10:09:17	42 of 59, education_boys_middle, 71_Bajaur_upgrade_dry
# 10:09:34	43 of 59, education_boys_middle, 72_Bajaur_upgrade_dry
# 10:09:50	44 of 59, education_boys_middle, 73_Bajaur_upgrade_dry
# 10:10:18	45 of 59, education_boys_middle, 74_Bajaur_upgrade_dry
# 10:10:26	46 of 59, education_boys_middle, 75_Bajaur_upgrade_dry
# 10:10:40	47 of 59, education_boys_middle, 77_Khuber_upgrade_dry
# 10:11:14	48 of 59, education_boys_middle, 78_Khuber_upgrade_dry
# 10:12:00	49 of 59, education_boys_middle, 7_LowerChitral_upgrade_dry
# 10:15:01	50 of 59, education_boys_middle, 80_Khuber_upgrade_dry
# 10:15:14	51 of 59, education_boys_middle, 81_Khuber_upgrade_dry
# 10:15:21	52 of 59, education_boys_middle, 82_Khuber_upgrade_dry
# 10:15:34	53 of 59, education_boys_middle, 83_Kurram_upgrade_dry
# 10:15:47	54 of 59, education_boys_middle, 84_Kurram_upgrade_dry
# 10:16:01	55 of 59, education_boys_middle, 85_NorthWaziristan_upgrade_dry
# 10:16:19	56 of 59, education_boys_middle, 86_NorthWaziristan_upgrade_dry
# 10:16:49	57 of 59, education_boys_middle, 87_NorthWaziristan_upgrade_dry
# 10:17:29	58 of 59, education_boys_middle, 8_LowerChitral_upgrade_dry
# 10:17:58	59 of 59, education_boys_middle, 9_LowerChitral_upgrade_dry
# 10:18:03	7 of 24 destinations: education_boys_primary
# 10:18:03	1 of 59, education_boys_primary, 10_LowerChitral_upgrade_dry
# 10:18:07	2 of 59, education_boys_primary, 11_LowerChitral_upgrade_dry
# 10:18:11	3 of 59, education_boys_primary, 12_Kohistan_upgrade_dry
# 10:18:27	4 of 59, education_boys_primary, 13_Kohistan_upgrade_dry
# 10:18:42	5 of 59, education_boys_primary, 14_Kohistan_upgrade_dry
# 10:18:49	6 of 59, education_boys_primary, 15_Kohistan_upgrade_dry
# 10:18:56	7 of 59, education_boys_primary, 17_Torghar_upgrade_dry
# 10:19:00	8 of 59, education_boys_primary, 18_Torghar_upgrade_dry
# 10:19:34	9 of 59, education_boys_primary, 19_Hangu_upgrade_dry
# 10:19:38	10 of 59, education_boys_primary, 1_UpperChitral_upgrade_dry
# 10:19:43	11 of 59, education_boys_primary, 20_Hangu_upgrade_dry
# 10:19:50	12 of 59, education_boys_primary, 21_Hangu_upgrade_dry
# 10:20:01	13 of 59, education_boys_primary, 22_Hangu_upgrade_dry
# 10:20:03	14 of 59, education_boys_primary, 23_Hangu_upgrade_dry
# 10:20:07	15 of 59, education_boys_primary, 24_Karak_upgrade_dry
# 10:20:10	16 of 59, education_boys_primary, 25_Karak_upgrade_dry
# 10:20:18	17 of 59, education_boys_primary, 26_Karak_upgrade_dry
# 10:20:21	18 of 59, education_boys_primary, 2_UpperChitral_upgrade_dry
# 10:20:49	19 of 59, education_boys_primary, 31_Karak_upgrade_dry
# 10:20:51	20 of 59, education_boys_primary, 32_Karak_upgrade_dry
# 10:20:53	21 of 59, education_boys_primary, 35_Karak_upgrade_dry
# 10:20:56	22 of 59, education_boys_primary, 37_Karak_upgrade_dry
# 10:20:59	23 of 59, education_boys_primary, 38_Karak_upgrade_dry
# 10:21:01	24 of 59, education_boys_primary, 3_UpperChitral_upgrade_dry
# 10:21:06	25 of 59, education_boys_primary, 41_Karak_upgrade_dry
# 10:21:12	26 of 59, education_boys_primary, 42_Karak_upgrade_dry
# 10:21:14	27 of 59, education_boys_primary, 43_Karak_upgrade_dry
# 10:21:17	28 of 59, education_boys_primary, 4_UpperChitral_upgrade_dry
# 10:21:21	29 of 59, education_boys_primary, 50_Laki_upgrade_dry
# 10:21:44	30 of 59, education_boys_primary, 52_Laki_upgrade_dry
# 10:21:47	31 of 59, education_boys_primary, 53_Laki_upgrade_dry
# 10:22:09	32 of 59, education_boys_primary, 57_D.I.Khan_upgrade_dry
# 10:22:23	33 of 59, education_boys_primary, 59_D.I.Khan_upgrade_dry
# 10:22:26	34 of 59, education_boys_primary, 5_UpperChitral_upgrade_dry
# 10:22:29	35 of 59, education_boys_primary, 60_D.I.Khan_upgrade_dry
# 10:22:37	36 of 59, education_boys_primary, 61_Tank_upgrade_dry
# 10:22:42	37 of 59, education_boys_primary, 62_Tank_upgrade_dry
# 10:23:01	38 of 59, education_boys_primary, 63_Tank_upgrade_dry
# 10:23:12	39 of 59, education_boys_primary, 64_Tank_upgrade_dry
# 10:23:15	40 of 59, education_boys_primary, 6_LowerChitral_upgrade_dry
# 10:23:22	41 of 59, education_boys_primary, 70_Bajaur_upgrade_dry
# 10:23:27	42 of 59, education_boys_primary, 71_Bajaur_upgrade_dry
# 10:23:34	43 of 59, education_boys_primary, 72_Bajaur_upgrade_dry
# 10:23:43	44 of 59, education_boys_primary, 73_Bajaur_upgrade_dry
# 10:24:03	45 of 59, education_boys_primary, 74_Bajaur_upgrade_dry
# 10:24:06	46 of 59, education_boys_primary, 75_Bajaur_upgrade_dry
# 10:24:10	47 of 59, education_boys_primary, 77_Khuber_upgrade_dry
# 10:24:30	48 of 59, education_boys_primary, 78_Khuber_upgrade_dry
# 10:25:08	49 of 59, education_boys_primary, 7_LowerChitral_upgrade_dry
# 10:27:51	50 of 59, education_boys_primary, 80_Khuber_upgrade_dry
# 10:27:58	51 of 59, education_boys_primary, 81_Khuber_upgrade_dry
# 10:28:02	52 of 59, education_boys_primary, 82_Khuber_upgrade_dry
# 10:28:07	53 of 59, education_boys_primary, 83_Kurram_upgrade_dry
# 10:28:12	54 of 59, education_boys_primary, 84_Kurram_upgrade_dry
# 10:28:19	55 of 59, education_boys_primary, 85_NorthWaziristan_upgrade_dry
# 10:28:26	56 of 59, education_boys_primary, 86_NorthWaziristan_upgrade_dry
# 10:28:53	57 of 59, education_boys_primary, 87_NorthWaziristan_upgrade_dry
# 10:29:15	58 of 59, education_boys_primary, 8_LowerChitral_upgrade_dry
# 10:29:39	59 of 59, education_boys_primary, 9_LowerChitral_upgrade_dry
# 10:29:42	8 of 24 destinations: education_girls
# 10:29:42	1 of 59, education_girls, 10_LowerChitral_upgrade_dry
# 10:29:48	2 of 59, education_girls, 11_LowerChitral_upgrade_dry
# 10:29:53	3 of 59, education_girls, 12_Kohistan_upgrade_dry
# 10:30:24	4 of 59, education_girls, 13_Kohistan_upgrade_dry
# 10:30:40	5 of 59, education_girls, 14_Kohistan_upgrade_dry
# 10:30:47	6 of 59, education_girls, 15_Kohistan_upgrade_dry
# 10:30:53	7 of 59, education_girls, 17_Torghar_upgrade_dry
# 10:31:00	8 of 59, education_girls, 18_Torghar_upgrade_dry
# 10:31:41	9 of 59, education_girls, 19_Hangu_upgrade_dry
# 10:31:45	10 of 59, education_girls, 1_UpperChitral_upgrade_dry
# 10:31:53	11 of 59, education_girls, 20_Hangu_upgrade_dry
# 10:32:06	12 of 59, education_girls, 21_Hangu_upgrade_dry
# 10:32:17	13 of 59, education_girls, 22_Hangu_upgrade_dry
# 10:32:19	14 of 59, education_girls, 23_Hangu_upgrade_dry
# 10:32:23	15 of 59, education_girls, 24_Karak_upgrade_dry
# 10:32:27	16 of 59, education_girls, 25_Karak_upgrade_dry
# 10:32:35	17 of 59, education_girls, 26_Karak_upgrade_dry
# 10:32:38	18 of 59, education_girls, 2_UpperChitral_upgrade_dry
# 10:33:08	19 of 59, education_girls, 31_Karak_upgrade_dry
# 10:33:10	20 of 59, education_girls, 32_Karak_upgrade_dry
# 10:33:12	21 of 59, education_girls, 35_Karak_upgrade_dry
# 10:33:15	22 of 59, education_girls, 37_Karak_upgrade_dry
# 10:33:17	23 of 59, education_girls, 38_Karak_upgrade_dry
# 10:33:19	24 of 59, education_girls, 3_UpperChitral_upgrade_dry
# 10:33:31	25 of 59, education_girls, 41_Karak_upgrade_dry
# 10:33:36	26 of 59, education_girls, 42_Karak_upgrade_dry
# 10:33:39	27 of 59, education_girls, 43_Karak_upgrade_dry
# 10:33:43	28 of 59, education_girls, 4_UpperChitral_upgrade_dry
# 10:33:46	29 of 59, education_girls, 50_Laki_upgrade_dry
# 10:34:11	30 of 59, education_girls, 52_Laki_upgrade_dry
# 10:34:13	31 of 59, education_girls, 53_Laki_upgrade_dry
# 10:34:34	32 of 59, education_girls, 57_D.I.Khan_upgrade_dry
# 10:34:48	33 of 59, education_girls, 59_D.I.Khan_upgrade_dry
# 10:34:51	34 of 59, education_girls, 5_UpperChitral_upgrade_dry
# 10:34:55	35 of 59, education_girls, 60_D.I.Khan_upgrade_dry
# 10:35:03	36 of 59, education_girls, 61_Tank_upgrade_dry
# 10:35:06	37 of 59, education_girls, 62_Tank_upgrade_dry
# 10:35:26	38 of 59, education_girls, 63_Tank_upgrade_dry
# 10:35:37	39 of 59, education_girls, 64_Tank_upgrade_dry
# 10:35:40	40 of 59, education_girls, 6_LowerChitral_upgrade_dry
# 10:35:48	41 of 59, education_girls, 70_Bajaur_upgrade_dry
# 10:35:52	42 of 59, education_girls, 71_Bajaur_upgrade_dry
# 10:35:58	43 of 59, education_girls, 72_Bajaur_upgrade_dry
# 10:36:07	44 of 59, education_girls, 73_Bajaur_upgrade_dry
# 10:36:31	45 of 59, education_girls, 74_Bajaur_upgrade_dry
# 10:36:35	46 of 59, education_girls, 75_Bajaur_upgrade_dry
# 10:36:39	47 of 59, education_girls, 77_Khuber_upgrade_dry
# 10:37:02	48 of 59, education_girls, 78_Khuber_upgrade_dry
# 10:37:38	49 of 59, education_girls, 7_LowerChitral_upgrade_dry
# 10:40:12	50 of 59, education_girls, 80_Khuber_upgrade_dry
# 10:40:18	51 of 59, education_girls, 81_Khuber_upgrade_dry
# 10:40:22	52 of 59, education_girls, 82_Khuber_upgrade_dry
# 10:40:29	53 of 59, education_girls, 83_Kurram_upgrade_dry
# 10:40:35	54 of 59, education_girls, 84_Kurram_upgrade_dry
# 10:40:45	55 of 59, education_girls, 85_NorthWaziristan_upgrade_dry
# 10:40:52	56 of 59, education_girls, 86_NorthWaziristan_upgrade_dry
# 10:41:16	57 of 59, education_girls, 87_NorthWaziristan_upgrade_dry
# 10:41:33	58 of 59, education_girls, 8_LowerChitral_upgrade_dry
# 10:41:56	59 of 59, education_girls, 9_LowerChitral_upgrade_dry
# 10:42:00	9 of 24 destinations: education_girls_high
# 10:42:00	1 of 59, education_girls_high, 10_LowerChitral_upgrade_dry
# 10:42:24	2 of 59, education_girls_high, 11_LowerChitral_upgrade_dry
# 10:42:41	3 of 59, education_girls_high, 12_Kohistan_upgrade_dry
# 10:46:08	4 of 59, education_girls_high, 13_Kohistan_upgrade_dry
# 10:47:24	5 of 59, education_girls_high, 14_Kohistan_upgrade_dry
# 10:48:19	6 of 59, education_girls_high, 15_Kohistan_upgrade_dry
# 10:49:29	7 of 59, education_girls_high, 17_Torghar_upgrade_dry
# 10:49:49	8 of 59, education_girls_high, 18_Torghar_upgrade_dry
# 10:50:57	9 of 59, education_girls_high, 19_Hangu_upgrade_dry
# 10:51:07	10 of 59, education_girls_high, 1_UpperChitral_upgrade_dry
# 10:51:41	11 of 59, education_girls_high, 20_Hangu_upgrade_dry
# 10:52:35	12 of 59, education_girls_high, 21_Hangu_upgrade_dry
# 10:52:56	13 of 59, education_girls_high, 22_Hangu_upgrade_dry
# 10:53:02	14 of 59, education_girls_high, 23_Hangu_upgrade_dry
# 10:53:26	15 of 59, education_girls_high, 24_Karak_upgrade_dry
# 10:53:32	16 of 59, education_girls_high, 25_Karak_upgrade_dry
# 10:53:52	17 of 59, education_girls_high, 26_Karak_upgrade_dry
# 10:53:58	18 of 59, education_girls_high, 2_UpperChitral_upgrade_dry
# 10:54:58	19 of 59, education_girls_high, 31_Karak_upgrade_dry
# 10:55:05	20 of 59, education_girls_high, 32_Karak_upgrade_dry
# 10:55:18	21 of 59, education_girls_high, 35_Karak_upgrade_dry
# 10:55:32	22 of 59, education_girls_high, 37_Karak_upgrade_dry
# 10:55:39	23 of 59, education_girls_high, 38_Karak_upgrade_dry
# 10:55:42	24 of 59, education_girls_high, 3_UpperChitral_upgrade_dry
# 10:56:19	25 of 59, education_girls_high, 41_Karak_upgrade_dry
# 10:56:34	26 of 59, education_girls_high, 42_Karak_upgrade_dry
# 10:56:47	27 of 59, education_girls_high, 43_Karak_upgrade_dry
# 10:56:54	28 of 59, education_girls_high, 4_UpperChitral_upgrade_dry
# 10:57:27	29 of 59, education_girls_high, 50_Laki_upgrade_dry
# 10:58:14	30 of 59, education_girls_high, 52_Laki_upgrade_dry
# 10:58:17	31 of 59, education_girls_high, 53_Laki_upgrade_dry
# 10:59:04	32 of 59, education_girls_high, 57_D.I.Khan_upgrade_dry
# 10:59:48	33 of 59, education_girls_high, 59_D.I.Khan_upgrade_dry
# 11:00:03	34 of 59, education_girls_high, 5_UpperChitral_upgrade_dry
# 11:00:27	35 of 59, education_girls_high, 60_D.I.Khan_upgrade_dry
# 11:00:52	36 of 59, education_girls_high, 61_Tank_upgrade_dry
# 11:01:18	37 of 59, education_girls_high, 62_Tank_upgrade_dry
# 11:01:46	38 of 59, education_girls_high, 63_Tank_upgrade_dry
# 11:02:12	39 of 59, education_girls_high, 64_Tank_upgrade_dry
# 11:02:20	40 of 59, education_girls_high, 6_LowerChitral_upgrade_dry
# 11:03:00	41 of 59, education_girls_high, 70_Bajaur_upgrade_dry
# 11:03:09	42 of 59, education_girls_high, 71_Bajaur_upgrade_dry
# 11:03:30	43 of 59, education_girls_high, 72_Bajaur_upgrade_dry
# 11:03:51	44 of 59, education_girls_high, 73_Bajaur_upgrade_dry
# 11:04:31	45 of 59, education_girls_high, 74_Bajaur_upgrade_dry
# 11:04:44	46 of 59, education_girls_high, 75_Bajaur_upgrade_dry
# 11:05:12	47 of 59, education_girls_high, 77_Khuber_upgrade_dry
# 11:06:04	48 of 59, education_girls_high, 78_Khuber_upgrade_dry
# 11:07:13	49 of 59, education_girls_high, 7_LowerChitral_upgrade_dry
# 11:10:14	50 of 59, education_girls_high, 80_Khuber_upgrade_dry
# 11:10:33	51 of 59, education_girls_high, 81_Khuber_upgrade_dry
# 11:10:49	52 of 59, education_girls_high, 82_Khuber_upgrade_dry
# 11:11:04	53 of 59, education_girls_high, 83_Kurram_upgrade_dry
# 11:11:18	54 of 59, education_girls_high, 84_Kurram_upgrade_dry
# 11:11:46	55 of 59, education_girls_high, 85_NorthWaziristan_upgrade_dry
# 11:12:54	56 of 59, education_girls_high, 86_NorthWaziristan_upgrade_dry
# 11:15:44	57 of 59, education_girls_high, 87_NorthWaziristan_upgrade_dry
# 11:17:51	58 of 59, education_girls_high, 8_LowerChitral_upgrade_dry
# 11:19:11	59 of 59, education_girls_high, 9_LowerChitral_upgrade_dry
# 11:19:44	10 of 24 destinations: education_girls_middle
# 11:19:44	1 of 59, education_girls_middle, 10_LowerChitral_upgrade_dry
# 11:19:56	2 of 59, education_girls_middle, 11_LowerChitral_upgrade_dry
# 11:20:11	3 of 59, education_girls_middle, 12_Kohistan_upgrade_dry
# 11:22:28	4 of 59, education_girls_middle, 13_Kohistan_upgrade_dry
# 11:22:53	5 of 59, education_girls_middle, 14_Kohistan_upgrade_dry
# 11:23:09	6 of 59, education_girls_middle, 15_Kohistan_upgrade_dry
# 11:23:30	7 of 59, education_girls_middle, 17_Torghar_upgrade_dry
# 11:23:49	8 of 59, education_girls_middle, 18_Torghar_upgrade_dry
# 11:24:48	9 of 59, education_girls_middle, 19_Hangu_upgrade_dry
# 11:24:54	10 of 59, education_girls_middle, 1_UpperChitral_upgrade_dry
# 11:25:14	11 of 59, education_girls_middle, 20_Hangu_upgrade_dry
# 11:26:11	12 of 59, education_girls_middle, 21_Hangu_upgrade_dry
# 11:26:29	13 of 59, education_girls_middle, 22_Hangu_upgrade_dry
# 11:26:35	14 of 59, education_girls_middle, 23_Hangu_upgrade_dry
# 11:26:52	15 of 59, education_girls_middle, 24_Karak_upgrade_dry
# 11:26:57	16 of 59, education_girls_middle, 25_Karak_upgrade_dry
# 11:27:17	17 of 59, education_girls_middle, 26_Karak_upgrade_dry
# 11:27:25	18 of 59, education_girls_middle, 2_UpperChitral_upgrade_dry
# 11:28:03	19 of 59, education_girls_middle, 31_Karak_upgrade_dry
# 11:28:09	20 of 59, education_girls_middle, 32_Karak_upgrade_dry
# 11:28:16	21 of 59, education_girls_middle, 35_Karak_upgrade_dry
# 11:28:28	22 of 59, education_girls_middle, 37_Karak_upgrade_dry
# 11:28:34	23 of 59, education_girls_middle, 38_Karak_upgrade_dry
# 11:28:40	24 of 59, education_girls_middle, 3_UpperChitral_upgrade_dry
# 11:29:15	25 of 59, education_girls_middle, 41_Karak_upgrade_dry
# 11:29:29	26 of 59, education_girls_middle, 42_Karak_upgrade_dry
# 11:29:43	27 of 59, education_girls_middle, 43_Karak_upgrade_dry
# 11:29:48	28 of 59, education_girls_middle, 4_UpperChitral_upgrade_dry
# 11:30:01	29 of 59, education_girls_middle, 50_Laki_upgrade_dry
# 11:30:42	30 of 59, education_girls_middle, 52_Laki_upgrade_dry
# 11:30:46	31 of 59, education_girls_middle, 53_Laki_upgrade_dry
# 11:31:21	32 of 59, education_girls_middle, 57_D.I.Khan_upgrade_dry
# 11:31:45	33 of 59, education_girls_middle, 59_D.I.Khan_upgrade_dry
# 11:31:57	34 of 59, education_girls_middle, 5_UpperChitral_upgrade_dry
# 11:32:09	35 of 59, education_girls_middle, 60_D.I.Khan_upgrade_dry
# 11:32:32	36 of 59, education_girls_middle, 61_Tank_upgrade_dry
# 11:32:48	37 of 59, education_girls_middle, 62_Tank_upgrade_dry
# 11:33:12	38 of 59, education_girls_middle, 63_Tank_upgrade_dry
# 11:33:29	39 of 59, education_girls_middle, 64_Tank_upgrade_dry
# 11:33:36	40 of 59, education_girls_middle, 6_LowerChitral_upgrade_dry
# 11:33:59	41 of 59, education_girls_middle, 70_Bajaur_upgrade_dry
# 11:34:09	42 of 59, education_girls_middle, 71_Bajaur_upgrade_dry
# 11:34:25	43 of 59, education_girls_middle, 72_Bajaur_upgrade_dry
# 11:34:44	44 of 59, education_girls_middle, 73_Bajaur_upgrade_dry
# 11:35:20	45 of 59, education_girls_middle, 74_Bajaur_upgrade_dry
# 11:35:30	46 of 59, education_girls_middle, 75_Bajaur_upgrade_dry
# 11:35:47	47 of 59, education_girls_middle, 77_Khuber_upgrade_dry
# 11:36:41	48 of 59, education_girls_middle, 78_Khuber_upgrade_dry
# 11:37:46	49 of 59, education_girls_middle, 7_LowerChitral_upgrade_dry
# 11:41:04	50 of 59, education_girls_middle, 80_Khuber_upgrade_dry
# 11:41:16	51 of 59, education_girls_middle, 81_Khuber_upgrade_dry
# 11:41:27	52 of 59, education_girls_middle, 82_Khuber_upgrade_dry
# 11:41:42	53 of 59, education_girls_middle, 83_Kurram_upgrade_dry
# 11:42:04	54 of 59, education_girls_middle, 84_Kurram_upgrade_dry
# 11:42:25	55 of 59, education_girls_middle, 85_NorthWaziristan_upgrade_dry
# 11:42:52	56 of 59, education_girls_middle, 86_NorthWaziristan_upgrade_dry
# 11:43:46	57 of 59, education_girls_middle, 87_NorthWaziristan_upgrade_dry
# 11:44:52	58 of 59, education_girls_middle, 8_LowerChitral_upgrade_dry
# 11:45:48	59 of 59, education_girls_middle, 9_LowerChitral_upgrade_dry
# 11:46:13	11 of 24 destinations: education_girls_primary
# 11:46:13	1 of 59, education_girls_primary, 10_LowerChitral_upgrade_dry
# 11:46:20	2 of 59, education_girls_primary, 11_LowerChitral_upgrade_dry
# 11:46:33	3 of 59, education_girls_primary, 12_Kohistan_upgrade_dry
# 11:47:05	4 of 59, education_girls_primary, 13_Kohistan_upgrade_dry
# 11:47:24	5 of 59, education_girls_primary, 14_Kohistan_upgrade_dry
# 11:47:31	6 of 59, education_girls_primary, 15_Kohistan_upgrade_dry
# 11:47:41	7 of 59, education_girls_primary, 17_Torghar_upgrade_dry
# 11:47:49	8 of 59, education_girls_primary, 18_Torghar_upgrade_dry
# 11:48:38	9 of 59, education_girls_primary, 19_Hangu_upgrade_dry
# 11:48:42	10 of 59, education_girls_primary, 1_UpperChitral_upgrade_dry
# 11:48:51	11 of 59, education_girls_primary, 20_Hangu_upgrade_dry
# 11:49:03	12 of 59, education_girls_primary, 21_Hangu_upgrade_dry
# 11:49:15	13 of 59, education_girls_primary, 22_Hangu_upgrade_dry
# 11:49:17	14 of 59, education_girls_primary, 23_Hangu_upgrade_dry
# 11:49:20	15 of 59, education_girls_primary, 24_Karak_upgrade_dry
# 11:49:24	16 of 59, education_girls_primary, 25_Karak_upgrade_dry
# 11:49:33	17 of 59, education_girls_primary, 26_Karak_upgrade_dry
# 11:49:36	18 of 59, education_girls_primary, 2_UpperChitral_upgrade_dry
# 11:50:10	19 of 59, education_girls_primary, 31_Karak_upgrade_dry
# 11:50:12	20 of 59, education_girls_primary, 32_Karak_upgrade_dry
# 11:50:15	21 of 59, education_girls_primary, 35_Karak_upgrade_dry
# 11:50:18	22 of 59, education_girls_primary, 37_Karak_upgrade_dry
# 11:50:20	23 of 59, education_girls_primary, 38_Karak_upgrade_dry
# 11:50:23	24 of 59, education_girls_primary, 3_UpperChitral_upgrade_dry
# 11:50:43	25 of 59, education_girls_primary, 41_Karak_upgrade_dry
# 11:50:50	26 of 59, education_girls_primary, 42_Karak_upgrade_dry
# 11:50:53	27 of 59, education_girls_primary, 43_Karak_upgrade_dry
# 11:50:56	28 of 59, education_girls_primary, 4_UpperChitral_upgrade_dry
# 11:51:02	29 of 59, education_girls_primary, 50_Laki_upgrade_dry
# 11:51:33	30 of 59, education_girls_primary, 52_Laki_upgrade_dry
# 11:51:35	31 of 59, education_girls_primary, 53_Laki_upgrade_dry
# 11:52:02	32 of 59, education_girls_primary, 57_D.I.Khan_upgrade_dry
# 11:52:23	33 of 59, education_girls_primary, 59_D.I.Khan_upgrade_dry
# 11:52:28	34 of 59, education_girls_primary, 5_UpperChitral_upgrade_dry
# 11:52:33	35 of 59, education_girls_primary, 60_D.I.Khan_upgrade_dry
# 11:52:45	36 of 59, education_girls_primary, 61_Tank_upgrade_dry
# 11:52:49	37 of 59, education_girls_primary, 62_Tank_upgrade_dry
# 11:53:10	38 of 59, education_girls_primary, 63_Tank_upgrade_dry
# 11:53:25	39 of 59, education_girls_primary, 64_Tank_upgrade_dry
# 11:53:28	40 of 59, education_girls_primary, 6_LowerChitral_upgrade_dry
# 11:53:37	41 of 59, education_girls_primary, 70_Bajaur_upgrade_dry
# 11:53:44	42 of 59, education_girls_primary, 71_Bajaur_upgrade_dry
# 11:53:52	43 of 59, education_girls_primary, 72_Bajaur_upgrade_dry
# 11:54:03	44 of 59, education_girls_primary, 73_Bajaur_upgrade_dry
# 11:54:28	45 of 59, education_girls_primary, 74_Bajaur_upgrade_dry
# 11:54:32	46 of 59, education_girls_primary, 75_Bajaur_upgrade_dry
# 11:54:37	47 of 59, education_girls_primary, 77_Khuber_upgrade_dry
# 11:55:01	48 of 59, education_girls_primary, 78_Khuber_upgrade_dry
# 11:55:37	49 of 59, education_girls_primary, 7_LowerChitral_upgrade_dry
# 11:58:28	50 of 59, education_girls_primary, 80_Khuber_upgrade_dry
# 11:58:33	51 of 59, education_girls_primary, 81_Khuber_upgrade_dry
# 11:58:37	52 of 59, education_girls_primary, 82_Khuber_upgrade_dry
# 11:58:43	53 of 59, education_girls_primary, 83_Kurram_upgrade_dry
# 11:58:49	54 of 59, education_girls_primary, 84_Kurram_upgrade_dry
# 11:59:01	55 of 59, education_girls_primary, 85_NorthWaziristan_upgrade_dry
# 11:59:10	56 of 59, education_girls_primary, 86_NorthWaziristan_upgrade_dry
# 11:59:37	57 of 59, education_girls_primary, 87_NorthWaziristan_upgrade_dry
# 11:59:59	58 of 59, education_girls_primary, 8_LowerChitral_upgrade_dry
# 12:00:30	59 of 59, education_girls_primary, 9_LowerChitral_upgrade_dry
# 12:00:35	12 of 24 destinations: education_high
# 12:00:35	1 of 59, education_high, 10_LowerChitral_upgrade_dry
# 12:00:48	2 of 59, education_high, 11_LowerChitral_upgrade_dry
# 12:01:04	3 of 59, education_high, 12_Kohistan_upgrade_dry
# 12:02:31	4 of 59, education_high, 13_Kohistan_upgrade_dry
# 12:02:57	5 of 59, education_high, 14_Kohistan_upgrade_dry
# 12:03:12	6 of 59, education_high, 15_Kohistan_upgrade_dry
# 12:03:31	7 of 59, education_high, 17_Torghar_upgrade_dry
# 12:03:47	8 of 59, education_high, 18_Torghar_upgrade_dry
# 12:04:38	9 of 59, education_high, 19_Hangu_upgrade_dry
# 12:04:43	10 of 59, education_high, 1_UpperChitral_upgrade_dry
# 12:04:57	11 of 59, education_high, 20_Hangu_upgrade_dry
# 12:05:14	12 of 59, education_high, 21_Hangu_upgrade_dry
# 12:05:27	13 of 59, education_high, 22_Hangu_upgrade_dry
# 12:05:33	14 of 59, education_high, 23_Hangu_upgrade_dry
# 12:05:44	15 of 59, education_high, 24_Karak_upgrade_dry
# 12:05:50	16 of 59, education_high, 25_Karak_upgrade_dry
# 12:06:07	17 of 59, education_high, 26_Karak_upgrade_dry
# 12:06:11	18 of 59, education_high, 2_UpperChitral_upgrade_dry
# 12:06:45	19 of 59, education_high, 31_Karak_upgrade_dry
# 12:06:49	20 of 59, education_high, 32_Karak_upgrade_dry
# 12:06:56	21 of 59, education_high, 35_Karak_upgrade_dry
# 12:07:09	22 of 59, education_high, 37_Karak_upgrade_dry
# 12:07:12	23 of 59, education_high, 38_Karak_upgrade_dry
# 12:07:15	24 of 59, education_high, 3_UpperChitral_upgrade_dry
# 12:07:37	25 of 59, education_high, 41_Karak_upgrade_dry
# 12:07:44	26 of 59, education_high, 42_Karak_upgrade_dry
# 12:07:50	27 of 59, education_high, 43_Karak_upgrade_dry
# 12:07:55	28 of 59, education_high, 4_UpperChitral_upgrade_dry
# 12:08:02	29 of 59, education_high, 50_Laki_upgrade_dry
# 12:08:36	30 of 59, education_high, 52_Laki_upgrade_dry
# 12:08:39	31 of 59, education_high, 53_Laki_upgrade_dry
# 12:09:14	32 of 59, education_high, 57_D.I.Khan_upgrade_dry
# 12:09:35	33 of 59, education_high, 59_D.I.Khan_upgrade_dry
# 12:09:44	34 of 59, education_high, 5_UpperChitral_upgrade_dry
# 12:09:51	35 of 59, education_high, 60_D.I.Khan_upgrade_dry
# 12:10:12	36 of 59, education_high, 61_Tank_upgrade_dry
# 12:10:18	37 of 59, education_high, 62_Tank_upgrade_dry
# 12:10:43	38 of 59, education_high, 63_Tank_upgrade_dry
# 12:11:01	39 of 59, education_high, 64_Tank_upgrade_dry
# 12:11:07	40 of 59, education_high, 6_LowerChitral_upgrade_dry
# 12:11:26	41 of 59, education_high, 70_Bajaur_upgrade_dry
# 12:11:32	42 of 59, education_high, 71_Bajaur_upgrade_dry
# 12:11:51	43 of 59, education_high, 72_Bajaur_upgrade_dry
# 12:12:06	44 of 59, education_high, 73_Bajaur_upgrade_dry
# 12:12:41	45 of 59, education_high, 74_Bajaur_upgrade_dry
# 12:12:47	46 of 59, education_high, 75_Bajaur_upgrade_dry
# 12:13:01	47 of 59, education_high, 77_Khuber_upgrade_dry
# 12:13:26	48 of 59, education_high, 78_Khuber_upgrade_dry
# 12:14:10	49 of 59, education_high, 7_LowerChitral_upgrade_dry
# 12:17:03	50 of 59, education_high, 80_Khuber_upgrade_dry
# 12:17:21	51 of 59, education_high, 81_Khuber_upgrade_dry
# 12:17:35	52 of 59, education_high, 82_Khuber_upgrade_dry
# 12:17:46	53 of 59, education_high, 83_Kurram_upgrade_dry
# 12:17:51	54 of 59, education_high, 84_Kurram_upgrade_dry
# 12:18:12	55 of 59, education_high, 85_NorthWaziristan_upgrade_dry
# 12:18:31	56 of 59, education_high, 86_NorthWaziristan_upgrade_dry
# 12:19:16	57 of 59, education_high, 87_NorthWaziristan_upgrade_dry
# 12:20:14	58 of 59, education_high, 8_LowerChitral_upgrade_dry
# 12:20:59	59 of 59, education_high, 9_LowerChitral_upgrade_dry
# 12:21:07	13 of 24 destinations: education_middle
# 12:21:07	1 of 59, education_middle, 10_LowerChitral_upgrade_dry
# 12:21:20	2 of 59, education_middle, 11_LowerChitral_upgrade_dry
# 12:21:27	3 of 59, education_middle, 12_Kohistan_upgrade_dry
# 12:22:10	4 of 59, education_middle, 13_Kohistan_upgrade_dry
# 12:22:33	5 of 59, education_middle, 14_Kohistan_upgrade_dry
# 12:22:43	6 of 59, education_middle, 15_Kohistan_upgrade_dry
# 12:22:54	7 of 59, education_middle, 17_Torghar_upgrade_dry
# 12:23:01	8 of 59, education_middle, 18_Torghar_upgrade_dry
# 12:23:51	9 of 59, education_middle, 19_Hangu_upgrade_dry
# 12:23:58	10 of 59, education_middle, 1_UpperChitral_upgrade_dry
# 12:24:15	11 of 59, education_middle, 20_Hangu_upgrade_dry
# 12:24:35	12 of 59, education_middle, 21_Hangu_upgrade_dry
# 12:24:50	13 of 59, education_middle, 22_Hangu_upgrade_dry
# 12:24:56	14 of 59, education_middle, 23_Hangu_upgrade_dry
# 12:25:06	15 of 59, education_middle, 24_Karak_upgrade_dry
# 12:25:13	16 of 59, education_middle, 25_Karak_upgrade_dry
# 12:25:32	17 of 59, education_middle, 26_Karak_upgrade_dry
# 12:25:38	18 of 59, education_middle, 2_UpperChitral_upgrade_dry
# 12:26:13	19 of 59, education_middle, 31_Karak_upgrade_dry
# 12:26:16	20 of 59, education_middle, 32_Karak_upgrade_dry
# 12:26:19	21 of 59, education_middle, 35_Karak_upgrade_dry
# 12:26:29	22 of 59, education_middle, 37_Karak_upgrade_dry
# 12:26:32	23 of 59, education_middle, 38_Karak_upgrade_dry
# 12:26:34	24 of 59, education_middle, 3_UpperChitral_upgrade_dry
# 12:26:57	25 of 59, education_middle, 41_Karak_upgrade_dry
# 12:27:06	26 of 59, education_middle, 42_Karak_upgrade_dry
# 12:27:12	27 of 59, education_middle, 43_Karak_upgrade_dry
# 12:27:16	28 of 59, education_middle, 4_UpperChitral_upgrade_dry
# 12:27:23	29 of 59, education_middle, 50_Laki_upgrade_dry
# 12:28:03	30 of 59, education_middle, 52_Laki_upgrade_dry
# 12:28:07	31 of 59, education_middle, 53_Laki_upgrade_dry
# 12:28:40	32 of 59, education_middle, 57_D.I.Khan_upgrade_dry
# 12:29:07	33 of 59, education_middle, 59_D.I.Khan_upgrade_dry
# 12:29:16	34 of 59, education_middle, 5_UpperChitral_upgrade_dry
# 12:29:23	35 of 59, education_middle, 60_D.I.Khan_upgrade_dry
# 12:29:38	36 of 59, education_middle, 61_Tank_upgrade_dry
# 12:29:54	37 of 59, education_middle, 62_Tank_upgrade_dry
# 12:30:20	38 of 59, education_middle, 63_Tank_upgrade_dry
# 12:30:37	39 of 59, education_middle, 64_Tank_upgrade_dry
# 12:30:41	40 of 59, education_middle, 6_LowerChitral_upgrade_dry
# 12:30:55	41 of 59, education_middle, 70_Bajaur_upgrade_dry
# 12:31:04	42 of 59, education_middle, 71_Bajaur_upgrade_dry
# 12:31:15	43 of 59, education_middle, 72_Bajaur_upgrade_dry
# 12:31:31	44 of 59, education_middle, 73_Bajaur_upgrade_dry
# 12:32:02	45 of 59, education_middle, 74_Bajaur_upgrade_dry
# 12:32:08	46 of 59, education_middle, 75_Bajaur_upgrade_dry
# 12:32:23	47 of 59, education_middle, 77_Khuber_upgrade_dry
# 12:32:56	48 of 59, education_middle, 78_Khuber_upgrade_dry
# 12:33:37	49 of 59, education_middle, 7_LowerChitral_upgrade_dry
# 12:36:20	50 of 59, education_middle, 80_Khuber_upgrade_dry
# 12:36:30	51 of 59, education_middle, 81_Khuber_upgrade_dry
# 12:36:37	52 of 59, education_middle, 82_Khuber_upgrade_dry
# 12:36:46	53 of 59, education_middle, 83_Kurram_upgrade_dry
# 12:36:54	54 of 59, education_middle, 84_Kurram_upgrade_dry
# 12:37:04	55 of 59, education_middle, 85_NorthWaziristan_upgrade_dry
# 12:37:22	56 of 59, education_middle, 86_NorthWaziristan_upgrade_dry
# ...
# 17:27:01	19 of 59, health_secondary, 31_Karak_upgrade_dry
# 17:27:22	20 of 59, health_secondary, 32_Karak_upgrade_dry
# 17:27:44	21 of 59, health_secondary, 35_Karak_upgrade_dry
# 17:27:57	22 of 59, health_secondary, 37_Karak_upgrade_dry
# 17:28:11	23 of 59, health_secondary, 38_Karak_upgrade_dry
# 17:28:33	24 of 59, health_secondary, 3_UpperChitral_upgrade_dry
# 17:31:43	25 of 59, health_secondary, 41_Karak_upgrade_dry
# 17:32:08	26 of 59, health_secondary, 42_Karak_upgrade_dry
# 17:32:26	27 of 59, health_secondary, 43_Karak_upgrade_dry
# 17:32:45	28 of 59, health_secondary, 4_UpperChitral_upgrade_dry
# 17:33:58	29 of 59, health_secondary, 50_Laki_upgrade_dry
# 17:35:01	30 of 59, health_secondary, 52_Laki_upgrade_dry
# 17:35:22	31 of 59, health_secondary, 53_Laki_upgrade_dry
# 17:36:16	32 of 59, health_secondary, 57_D.I.Khan_upgrade_dry
# 17:37:02	33 of 59, health_secondary, 59_D.I.Khan_upgrade_dry
# 17:37:37	34 of 59, health_secondary, 5_UpperChitral_upgrade_dry
# 17:39:07	35 of 59, health_secondary, 60_D.I.Khan_upgrade_dry
# 17:39:49	36 of 59, health_secondary, 61_Tank_upgrade_dry
# 17:40:15	37 of 59, health_secondary, 62_Tank_upgrade_dry
# 17:40:46	38 of 59, health_secondary, 63_Tank_upgrade_dry
# 17:41:06	39 of 59, health_secondary, 64_Tank_upgrade_dry
# 17:41:13	40 of 59, health_secondary, 6_LowerChitral_upgrade_dry
# 17:42:31	41 of 59, health_secondary, 70_Bajaur_upgrade_dry
# 17:42:52	42 of 59, health_secondary, 71_Bajaur_upgrade_dry
# 17:43:16	43 of 59, health_secondary, 72_Bajaur_upgrade_dry
# 17:43:43	44 of 59, health_secondary, 73_Bajaur_upgrade_dry
# 17:44:18	45 of 59, health_secondary, 74_Bajaur_upgrade_dry
# 17:44:33	46 of 59, health_secondary, 75_Bajaur_upgrade_dry
# 17:44:46	47 of 59, health_secondary, 77_Khuber_upgrade_dry
# 17:45:47	48 of 59, health_secondary, 78_Khuber_upgrade_dry
# 17:46:57	49 of 59, health_secondary, 7_LowerChitral_upgrade_dry
# 17:51:34	50 of 59, health_secondary, 80_Khuber_upgrade_dry
# 17:51:48	51 of 59, health_secondary, 81_Khuber_upgrade_dry
# 17:52:04	52 of 59, health_secondary, 82_Khuber_upgrade_dry
# 17:52:21	53 of 59, health_secondary, 83_Kurram_upgrade_dry
# 17:52:37	54 of 59, health_secondary, 84_Kurram_upgrade_dry
# 17:53:00	55 of 59, health_secondary, 85_NorthWaziristan_upgrade_dry
# 17:54:24	56 of 59, health_secondary, 86_NorthWaziristan_upgrade_dry
# 17:57:08	57 of 59, health_secondary, 87_NorthWaziristan_upgrade_dry
# 17:59:32	58 of 59, health_secondary, 8_LowerChitral_upgrade_dry
# 18:01:17	59 of 59, health_secondary, 9_LowerChitral_upgrade_dry
# 18:02:15	21 of 24 destinations: health_tertiary
# 18:02:15	1 of 59, health_tertiary, 10_LowerChitral_upgrade_dry
# 18:07:02	2 of 59, health_tertiary, 11_LowerChitral_upgrade_dry
# 18:12:17	3 of 59, health_tertiary, 12_Kohistan_upgrade_dry
# 18:17:43	4 of 59, health_tertiary, 13_Kohistan_upgrade_dry
# 18:21:41	5 of 59, health_tertiary, 14_Kohistan_upgrade_dry
# 18:25:26	6 of 59, health_tertiary, 15_Kohistan_upgrade_dry
# 18:29:37	7 of 59, health_tertiary, 17_Torghar_upgrade_dry
# 18:31:08	8 of 59, health_tertiary, 18_Torghar_upgrade_dry
# 18:34:37	9 of 59, health_tertiary, 19_Hangu_upgrade_dry
# 18:36:34	10 of 59, health_tertiary, 1_UpperChitral_upgrade_dry
# 18:42:22	11 of 59, health_tertiary, 20_Hangu_upgrade_dry
# 18:47:22	12 of 59, health_tertiary, 21_Hangu_upgrade_dry
# 18:49:06	13 of 59, health_tertiary, 22_Hangu_upgrade_dry
# 18:51:03	14 of 59, health_tertiary, 23_Hangu_upgrade_dry
# 18:54:00	15 of 59, health_tertiary, 24_Karak_upgrade_dry
# 18:58:20	16 of 59, health_tertiary, 25_Karak_upgrade_dry
# 19:03:31	17 of 59, health_tertiary, 26_Karak_upgrade_dry
# 19:08:31	18 of 59, health_tertiary, 2_UpperChitral_upgrade_dry
# 19:15:25	19 of 59, health_tertiary, 31_Karak_upgrade_dry
# 19:20:23	20 of 59, health_tertiary, 32_Karak_upgrade_dry
# 19:26:04	21 of 59, health_tertiary, 35_Karak_upgrade_dry
# 19:29:40	22 of 59, health_tertiary, 37_Karak_upgrade_dry
# 19:33:34	23 of 59, health_tertiary, 38_Karak_upgrade_dry
# 19:36:46	24 of 59, health_tertiary, 3_UpperChitral_upgrade_dry
# 19:44:37	25 of 59, health_tertiary, 41_Karak_upgrade_dry
# 19:47:51	26 of 59, health_tertiary, 42_Karak_upgrade_dry
# 19:51:40	27 of 59, health_tertiary, 43_Karak_upgrade_dry
# 19:56:35	28 of 59, health_tertiary, 4_UpperChitral_upgrade_dry
# 20:02:42	29 of 59, health_tertiary, 50_Laki_upgrade_dry
# 20:12:06	30 of 59, health_tertiary, 52_Laki_upgrade_dry
# 20:19:21	31 of 59, health_tertiary, 53_Laki_upgrade_dry
# 20:30:08	32 of 59, health_tertiary, 57_D.I.Khan_upgrade_dry
# 20:40:47	33 of 59, health_tertiary, 59_D.I.Khan_upgrade_dry
# 20:49:31	34 of 59, health_tertiary, 5_UpperChitral_upgrade_dry
# 20:55:11	35 of 59, health_tertiary, 60_D.I.Khan_upgrade_dry
# 21:03:57	36 of 59, health_tertiary, 61_Tank_upgrade_dry
# 21:15:54	37 of 59, health_tertiary, 62_Tank_upgrade_dry
# 21:25:06	38 of 59, health_tertiary, 63_Tank_upgrade_dry
# 21:33:58	39 of 59, health_tertiary, 64_Tank_upgrade_dry
# 21:42:35	40 of 59, health_tertiary, 6_LowerChitral_upgrade_dry
# 21:46:33	41 of 59, health_tertiary, 70_Bajaur_upgrade_dry
# 21:48:08	42 of 59, health_tertiary, 71_Bajaur_upgrade_dry
# 21:50:30	43 of 59, health_tertiary, 72_Bajaur_upgrade_dry
# 21:52:57	44 of 59, health_tertiary, 73_Bajaur_upgrade_dry
# 21:56:10	45 of 59, health_tertiary, 74_Bajaur_upgrade_dry
# 21:57:56	46 of 59, health_tertiary, 75_Bajaur_upgrade_dry
# 22:00:22	47 of 59, health_tertiary, 77_Khuber_upgrade_dry
# 22:01:44	48 of 59, health_tertiary, 78_Khuber_upgrade_dry
# 22:03:11	49 of 59, health_tertiary, 7_LowerChitral_upgrade_dry
# 22:13:54	50 of 59, health_tertiary, 80_Khuber_upgrade_dry
# 22:14:25	51 of 59, health_tertiary, 81_Khuber_upgrade_dry
# 22:14:51	52 of 59, health_tertiary, 82_Khuber_upgrade_dry
# 22:15:17	53 of 59, health_tertiary, 83_Kurram_upgrade_dry
# 22:19:03	54 of 59, health_tertiary, 84_Kurram_upgrade_dry
# 22:23:14	55 of 59, health_tertiary, 85_NorthWaziristan_upgrade_dry
# 22:32:27	56 of 59, health_tertiary, 86_NorthWaziristan_upgrade_dry
# 22:41:52	57 of 59, health_tertiary, 87_NorthWaziristan_upgrade_dry
# 22:51:17	58 of 59, health_tertiary, 8_LowerChitral_upgrade_dry
# 22:55:58	59 of 59, health_tertiary, 9_LowerChitral_upgrade_dry
# 22:59:07	22 of 24 destinations: markets_All
# 22:59:07	1 of 59, markets_All, 10_LowerChitral_upgrade_dry
# 23:00:46	2 of 59, markets_All, 11_LowerChitral_upgrade_dry
# 23:01:54	3 of 59, markets_All, 12_Kohistan_upgrade_dry
# 23:06:38	4 of 59, markets_All, 13_Kohistan_upgrade_dry
# 23:09:08	5 of 59, markets_All, 14_Kohistan_upgrade_dry
# 23:10:42	6 of 59, markets_All, 15_Kohistan_upgrade_dry
# 23:12:22	7 of 59, markets_All, 17_Torghar_upgrade_dry
# 23:13:16	8 of 59, markets_All, 18_Torghar_upgrade_dry
# 23:15:19	9 of 59, markets_All, 19_Hangu_upgrade_dry
# 23:16:01	10 of 59, markets_All, 1_UpperChitral_upgrade_dry
# 23:17:55	11 of 59, markets_All, 20_Hangu_upgrade_dry
# 23:18:57	12 of 59, markets_All, 21_Hangu_upgrade_dry
# 23:19:29	13 of 59, markets_All, 22_Hangu_upgrade_dry
# 23:20:05	14 of 59, markets_All, 23_Hangu_upgrade_dry
# 23:21:11	15 of 59, markets_All, 24_Karak_upgrade_dry
# 23:21:53	16 of 59, markets_All, 25_Karak_upgrade_dry
# 23:22:53	17 of 59, markets_All, 26_Karak_upgrade_dry
# 23:23:22	18 of 59, markets_All, 2_UpperChitral_upgrade_dry
# 23:27:01	19 of 59, markets_All, 31_Karak_upgrade_dry
# 23:27:26	20 of 59, markets_All, 32_Karak_upgrade_dry
# 23:27:53	21 of 59, markets_All, 35_Karak_upgrade_dry
# 23:28:32	22 of 59, markets_All, 37_Karak_upgrade_dry
# 23:29:20	23 of 59, markets_All, 38_Karak_upgrade_dry
# 23:30:15	24 of 59, markets_All, 3_UpperChitral_upgrade_dry
# 23:33:39	25 of 59, markets_All, 41_Karak_upgrade_dry
# 23:34:40	26 of 59, markets_All, 42_Karak_upgrade_dry
# 23:35:21	27 of 59, markets_All, 43_Karak_upgrade_dry
# 23:35:43	28 of 59, markets_All, 4_UpperChitral_upgrade_dry
# 23:37:49	29 of 59, markets_All, 50_Laki_upgrade_dry
# 23:39:28	30 of 59, markets_All, 52_Laki_upgrade_dry
# 23:39:47	31 of 59, markets_All, 53_Laki_upgrade_dry
# 23:41:55	32 of 59, markets_All, 57_D.I.Khan_upgrade_dry
# 23:42:49	33 of 59, markets_All, 59_D.I.Khan_upgrade_dry
# 23:43:28	34 of 59, markets_All, 5_UpperChitral_upgrade_dry
# 23:45:49	35 of 59, markets_All, 60_D.I.Khan_upgrade_dry
# 23:46:51	36 of 59, markets_All, 61_Tank_upgrade_dry
# 23:48:11	37 of 59, markets_All, 62_Tank_upgrade_dry
# 23:50:27	38 of 59, markets_All, 63_Tank_upgrade_dry
# 23:52:03	39 of 59, markets_All, 64_Tank_upgrade_dry
# 23:53:40	40 of 59, markets_All, 6_LowerChitral_upgrade_dry
# 23:54:44	41 of 59, markets_All, 70_Bajaur_upgrade_dry
# 23:55:09	42 of 59, markets_All, 71_Bajaur_upgrade_dry
# 23:55:45	43 of 59, markets_All, 72_Bajaur_upgrade_dry
# 23:56:14	44 of 59, markets_All, 73_Bajaur_upgrade_dry
# 23:57:15	45 of 59, markets_All, 74_Bajaur_upgrade_dry
# 23:57:38	46 of 59, markets_All, 75_Bajaur_upgrade_dry
# 23:58:20	47 of 59, markets_All, 77_Khuber_upgrade_dry
# 23:59:34	48 of 59, markets_All, 78_Khuber_upgrade_dry
# 00:01:12	49 of 59, markets_All, 7_LowerChitral_upgrade_dry
# 00:07:26	50 of 59, markets_All, 80_Khuber_upgrade_dry
# 00:07:57	51 of 59, markets_All, 81_Khuber_upgrade_dry
# 00:08:25	52 of 59, markets_All, 82_Khuber_upgrade_dry
# 00:08:52	53 of 59, markets_All, 83_Kurram_upgrade_dry
# 00:12:00	54 of 59, markets_All, 84_Kurram_upgrade_dry
# 00:14:43	55 of 59, markets_All, 85_NorthWaziristan_upgrade_dry
# 00:16:31	56 of 59, markets_All, 86_NorthWaziristan_upgrade_dry
# 00:19:14	57 of 59, markets_All, 87_NorthWaziristan_upgrade_dry
# 00:22:20	58 of 59, markets_All, 8_LowerChitral_upgrade_dry
# 00:23:41	59 of 59, markets_All, 9_LowerChitral_upgrade_dry
# 00:24:18	23 of 24 destinations: markets_Central
# 00:24:18	1 of 59, markets_Central, 10_LowerChitral_upgrade_dry
# 00:32:08	2 of 59, markets_Central, 11_LowerChitral_upgrade_dry
# 00:40:09	3 of 59, markets_Central, 12_Kohistan_upgrade_dry
# 00:46:17	4 of 59, markets_Central, 13_Kohistan_upgrade_dry
# 00:50:41	5 of 59, markets_Central, 14_Kohistan_upgrade_dry
# 00:55:04	6 of 59, markets_Central, 15_Kohistan_upgrade_dry
# 00:59:32	7 of 59, markets_Central, 17_Torghar_upgrade_dry
# 01:01:04	8 of 59, markets_Central, 18_Torghar_upgrade_dry
# 01:05:05	9 of 59, markets_Central, 19_Hangu_upgrade_dry
# 01:10:08	10 of 59, markets_Central, 1_UpperChitral_upgrade_dry
# 01:18:12	11 of 59, markets_Central, 20_Hangu_upgrade_dry
# 01:26:40	12 of 59, markets_Central, 21_Hangu_upgrade_dry
# 01:31:00	13 of 59, markets_Central, 22_Hangu_upgrade_dry
# 01:35:42	14 of 59, markets_Central, 23_Hangu_upgrade_dry
# 01:41:44	15 of 59, markets_Central, 24_Karak_upgrade_dry
# 01:47:34	16 of 59, markets_Central, 25_Karak_upgrade_dry
# 01:53:53	17 of 59, markets_Central, 26_Karak_upgrade_dry
# 01:59:00	18 of 59, markets_Central, 2_UpperChitral_upgrade_dry
# 02:08:05	19 of 59, markets_Central, 31_Karak_upgrade_dry
# 02:13:09	20 of 59, markets_Central, 32_Karak_upgrade_dry
# 02:18:31	21 of 59, markets_Central, 35_Karak_upgrade_dry
# 02:24:36	22 of 59, markets_Central, 37_Karak_upgrade_dry
# 02:30:50	23 of 59, markets_Central, 38_Karak_upgrade_dry
# 02:36:03	24 of 59, markets_Central, 3_UpperChitral_upgrade_dry
# 02:45:09	25 of 59, markets_Central, 41_Karak_upgrade_dry
# 02:50:44	26 of 59, markets_Central, 42_Karak_upgrade_dry
# 02:57:20	27 of 59, markets_Central, 43_Karak_upgrade_dry
# 03:03:19	28 of 59, markets_Central, 4_UpperChitral_upgrade_dry
# 03:11:43	29 of 59, markets_Central, 50_Laki_upgrade_dry
# 03:19:53	30 of 59, markets_Central, 52_Laki_upgrade_dry
# 03:27:13	31 of 59, markets_Central, 53_Laki_upgrade_dry
# 03:36:06	32 of 59, markets_Central, 57_D.I.Khan_upgrade_dry
# 03:44:56	33 of 59, markets_Central, 59_D.I.Khan_upgrade_dry
# 03:53:20	34 of 59, markets_Central, 5_UpperChitral_upgrade_dry
# 04:01:47	35 of 59, markets_Central, 60_D.I.Khan_upgrade_dry
# 04:10:30	36 of 59, markets_Central, 61_Tank_upgrade_dry
# 04:18:57	37 of 59, markets_Central, 62_Tank_upgrade_dry
# 04:28:48	38 of 59, markets_Central, 63_Tank_upgrade_dry
# 04:37:19	39 of 59, markets_Central, 64_Tank_upgrade_dry
# 04:46:00	40 of 59, markets_Central, 6_LowerChitral_upgrade_dry
# 04:52:47	41 of 59, markets_Central, 70_Bajaur_upgrade_dry
# 04:54:40	42 of 59, markets_Central, 71_Bajaur_upgrade_dry
# 04:57:16	43 of 59, markets_Central, 72_Bajaur_upgrade_dry
# 04:59:56	44 of 59, markets_Central, 73_Bajaur_upgrade_dry
# 05:03:32	45 of 59, markets_Central, 74_Bajaur_upgrade_dry
# 05:05:20	46 of 59, markets_Central, 75_Bajaur_upgrade_dry
# 05:07:53	47 of 59, markets_Central, 77_Khuber_upgrade_dry
# 05:10:57	48 of 59, markets_Central, 78_Khuber_upgrade_dry
# 05:14:43	49 of 59, markets_Central, 7_LowerChitral_upgrade_dry
# 05:27:02	50 of 59, markets_Central, 80_Khuber_upgrade_dry
# 05:29:16	51 of 59, markets_Central, 81_Khuber_upgrade_dry
# 05:31:25	52 of 59, markets_Central, 82_Khuber_upgrade_dry
# 05:33:11	53 of 59, markets_Central, 83_Kurram_upgrade_dry
# 05:40:01	54 of 59, markets_Central, 84_Kurram_upgrade_dry
# 05:47:29	55 of 59, markets_Central, 85_NorthWaziristan_upgrade_dry
# 05:56:07	56 of 59, markets_Central, 86_NorthWaziristan_upgrade_dry
# 06:05:14	57 of 59, markets_Central, 87_NorthWaziristan_upgrade_dry
# 06:14:23	58 of 59, markets_Central, 8_LowerChitral_upgrade_dry
# 06:23:40	59 of 59, markets_Central, 9_LowerChitral_upgrade_dry
# 06:29:26	24 of 24 destinations: Provincial_HQ
# 06:29:26	1 of 59, Provincial_HQ, 10_LowerChitral_upgrade_dry
# 06:38:29	2 of 59, Provincial_HQ, 11_LowerChitral_upgrade_dry
# 06:47:19	3 of 59, Provincial_HQ, 12_Kohistan_upgrade_dry
# 06:58:08	4 of 59, Provincial_HQ, 13_Kohistan_upgrade_dry
# 07:07:50	5 of 59, Provincial_HQ, 14_Kohistan_upgrade_dry
# 07:17:22	6 of 59, Provincial_HQ, 15_Kohistan_upgrade_dry
# 07:26:34	7 of 59, Provincial_HQ, 17_Torghar_upgrade_dry
# 07:32:06	8 of 59, Provincial_HQ, 18_Torghar_upgrade_dry
# 07:40:36	9 of 59, Provincial_HQ, 19_Hangu_upgrade_dry
# 07:42:43	10 of 59, Provincial_HQ, 1_UpperChitral_upgrade_dry
# 07:52:57	11 of 59, Provincial_HQ, 20_Hangu_upgrade_dry
# 07:58:06	12 of 59, Provincial_HQ, 21_Hangu_upgrade_dry
# 07:59:54	13 of 59, Provincial_HQ, 22_Hangu_upgrade_dry
# 08:01:58	14 of 59, Provincial_HQ, 23_Hangu_upgrade_dry
# 08:05:07	15 of 59, Provincial_HQ, 24_Karak_upgrade_dry
# 08:09:32	16 of 59, Provincial_HQ, 25_Karak_upgrade_dry
# 08:14:51	17 of 59, Provincial_HQ, 26_Karak_upgrade_dry
# 08:20:08	18 of 59, Provincial_HQ, 2_UpperChitral_upgrade_dry
# 08:31:27	19 of 59, Provincial_HQ, 31_Karak_upgrade_dry
# 08:36:54	20 of 59, Provincial_HQ, 32_Karak_upgrade_dry
# 08:42:37	21 of 59, Provincial_HQ, 35_Karak_upgrade_dry
# 08:46:17	22 of 59, Provincial_HQ, 37_Karak_upgrade_dry
# 08:50:29	23 of 59, Provincial_HQ, 38_Karak_upgrade_dry
# 08:54:06	24 of 59, Provincial_HQ, 3_UpperChitral_upgrade_dry
# 09:05:12	25 of 59, Provincial_HQ, 41_Karak_upgrade_dry
# 09:08:49	26 of 59, Provincial_HQ, 42_Karak_upgrade_dry
# 09:12:59	27 of 59, Provincial_HQ, 43_Karak_upgrade_dry
# 09:18:21	28 of 59, Provincial_HQ, 4_UpperChitral_upgrade_dry
# 09:28:34	29 of 59, Provincial_HQ, 50_Laki_upgrade_dry
# 09:37:21	30 of 59, Provincial_HQ, 52_Laki_upgrade_dry
# 09:44:59	31 of 59, Provincial_HQ, 53_Laki_upgrade_dry
# 09:54:19	32 of 59, Provincial_HQ, 57_D.I.Khan_upgrade_dry
# 10:03:48	33 of 59, Provincial_HQ, 59_D.I.Khan_upgrade_dry
# 10:14:21	34 of 59, Provincial_HQ, 5_UpperChitral_upgrade_dry
# 10:24:47	35 of 59, Provincial_HQ, 60_D.I.Khan_upgrade_dry
# 10:34:46	36 of 59, Provincial_HQ, 61_Tank_upgrade_dry
# 10:44:29	37 of 59, Provincial_HQ, 62_Tank_upgrade_dry
# 10:54:50	38 of 59, Provincial_HQ, 63_Tank_upgrade_dry
# 11:04:18	39 of 59, Provincial_HQ, 64_Tank_upgrade_dry
# 11:14:28	40 of 59, Provincial_HQ, 6_LowerChitral_upgrade_dry
# 11:23:39	41 of 59, Provincial_HQ, 70_Bajaur_upgrade_dry
# 11:26:37	42 of 59, Provincial_HQ, 71_Bajaur_upgrade_dry
# 11:29:46	43 of 59, Provincial_HQ, 72_Bajaur_upgrade_dry
# 11:32:58	44 of 59, Provincial_HQ, 73_Bajaur_upgrade_dry
# 11:37:07	45 of 59, Provincial_HQ, 74_Bajaur_upgrade_dry
# 11:39:27	46 of 59, Provincial_HQ, 75_Bajaur_upgrade_dry
# 11:42:06	47 of 59, Provincial_HQ, 77_Khuber_upgrade_dry
# 11:43:13	48 of 59, Provincial_HQ, 78_Khuber_upgrade_dry
# 11:44:37	49 of 59, Provincial_HQ, 7_LowerChitral_upgrade_dry
# 11:57:48	50 of 59, Provincial_HQ, 80_Khuber_upgrade_dry
# 11:58:13	51 of 59, Provincial_HQ, 81_Khuber_upgrade_dry
# 11:58:34	52 of 59, Provincial_HQ, 82_Khuber_upgrade_dry
# 11:59:02	53 of 59, Provincial_HQ, 83_Kurram_upgrade_dry
# 12:02:49	54 of 59, Provincial_HQ, 84_Kurram_upgrade_dry
# 12:06:49	55 of 59, Provincial_HQ, 85_NorthWaziristan_upgrade_dry

# %% [markdown]
# All done. Move on to the next step.
